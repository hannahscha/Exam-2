# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahscha/Exam-2/blob/main/Exam_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Loading

# %%
# Import the pandas library for data manipulation and analysis.
import pandas as pd

# Specify the file path to the Excel file.
# Make sure to replace 'path/to/your/file.xlsx' with the actual path to your file.
file_path = '/content/Test2_dataset.xlsx'

# Read the Excel file into a pandas DataFrame.
# The `read_excel()` function is used to load data from an Excel file.
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame.
# This helps to visualize the data and get a sense of its structure.
print(df.head())

# Print the column names of the DataFrame.
# This shows the names of the variables or features in the dataset.
print(df.columns)

# Get the data types of each column in the DataFrame.
# This is important to understand the nature of the data in each column.
print(df.dtypes)

# Summary:
# This code snippet demonstrates how to load an Excel file into a pandas DataFrame.
# It includes steps to display the first few rows of the data,
# print the column names, and check the data types of each column.
# This information is crucial for understanding the dataset's structure and content.
# Out:
#              Catalyst  Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  \
# 0         Ni−SiO2‑550                  0.15                   650        10.0
# 1         Ni−SiO2‑750                  0.15                   650        10.0
# 2   Ni/Sn0.2−SiO2‑550                  0.15                   650        10.0
# 3   Ni/Sn0.2−SiO2‑750                  0.15                   650        10.0
# 4  Ni/Sn0.05−SiO2‑550                  0.15                   650        10.0
#
#    Reaction Time  Pore Size  Pore Volume  Surface Area  \
# 0            0.5        4.7         0.58         476.0
# 1            0.5        4.7         0.58         476.0
# 2            0.5        5.2         0.58         455.0
# 3            0.5        5.2         0.58         455.0
# 4            0.5        4.8         0.82         599.0
#
#    H2-TPR Peak Temperature  Ni Particle Size  Ni Dispersion  \
# 0                    640.0               2.9            NaN
# 1                    640.0               4.6            NaN
# 2                    457.0               2.9            NaN
# 3                    457.0               4.6            NaN
# 4                    558.0               3.9            NaN
#
#    Modifier Electronegativity   GHSV  CH4 Conversion  CO2 Conversion  \
# 0                        1.96  60000            68.5            73.6
# 1                        1.96  60000            66.9            72.4
# 2                        1.96  60000            18.4            26.1
# 3                        1.96  60000            14.6            19.9
# 4                        1.96  60000            61.3            74.0
#
#    Syngas_Ratio
# 0           0.7
# 1           0.7
# 2           1.0
# 3           0.9
# 4           0.7
# Index(['Catalyst', 'Ratio of CH4 in Feed', 'Reaction Temperature',
#        'Ni Loading', 'Reaction Time', 'Pore Size', 'Pore Volume',
#        'Surface Area', 'H2-TPR Peak Temperature', 'Ni Particle Size',
#        'Ni Dispersion', 'Modifier Electronegativity', 'GHSV', 'CH4 Conversion',
#        'CO2 Conversion', 'Syngas_Ratio'],
#       dtype='object')
# Catalyst                       object
# Ratio of CH4 in Feed          float64
# Reaction Temperature            int64
# Ni Loading                    float64
# Reaction Time                 float64
# Pore Size                     float64
# Pore Volume                   float64
# Surface Area                  float64
# H2-TPR Peak Temperature       float64
# Ni Particle Size              float64
# Ni Dispersion                 float64
# Modifier Electronegativity    float64
# GHSV                            int64
# CH4 Conversion                float64
# CO2 Conversion                float64
# Syngas_Ratio                  float64
# dtype: object

# %% [markdown]
# Step 2: Checking for missing data

# %%
import pandas as pd
# Step 1: Data Loading (same as before)
file_path = '/content/Test2_dataset.xlsx'
df = pd.read_excel(file_path)

# Step 2: Checking for missing data (same as before)
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)

# Step 3: Handling Missing Data

# We'll choose to fill missing values with the mean for numerical columns
# and the mode for categorical columns. This is a common approach
# when dealing with missing values and can provide a reasonable estimate.

# Identify numerical columns
numerical_cols = df.select_dtypes(include=['number']).columns

# Identify categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Iterate through numerical columns and fill missing values with the mean
print("Filling missing values in numerical columns with the mean...")
for col in numerical_cols:
  if df[col].isnull().any():  # Only fill if there are missing values
    df[col].fillna(df[col].mean(), inplace=True)


# Iterate through categorical columns and fill missing values with the mode
print("Filling missing values in categorical columns with the mode...")
for col in categorical_cols:
  if df[col].isnull().any():  # Only fill if there are missing values
    df[col].fillna(df[col].mode()[0], inplace=True)


# Step 4: Verify Missing Values (Optional)
missing_values_after_handling = df.isnull().sum()
print("\nMissing values after handling:\n", missing_values_after_handling)
# Out:
# Missing values per column:
#  Catalyst                         0
# Ratio of CH4 in Feed             0
# Reaction Temperature             0
# Ni Loading                       0
# Reaction Time                    0
# Pore Size                        0
# Pore Volume                      0
# Surface Area                     0
# H2-TPR Peak Temperature          0
# Ni Particle Size                 0
# Ni Dispersion                 1056
# Modifier Electronegativity       0
# GHSV                             0
# CH4 Conversion                  49
# CO2 Conversion                  77
# Syngas_Ratio                    76
# dtype: int64
# Filling missing values in numerical columns with the mean...
# Filling missing values in categorical columns with the mode...
#
# Missing values after handling:
#  Catalyst                      0
# Ratio of CH4 in Feed          0
# Reaction Temperature          0
# Ni Loading                    0
# Reaction Time                 0
# Pore Size                     0
# Pore Volume                   0
# Surface Area                  0
# H2-TPR Peak Temperature       0
# Ni Particle Size              0
# Ni Dispersion                 0
# Modifier Electronegativity    0
# GHSV                          0
# CH4 Conversion                0
# CO2 Conversion                0
# Syngas_Ratio                  0
# dtype: int64

# %% [markdown]
# Step 3: Handling Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to detect outliers using the IQR method
def detect_outliers_iqr(data):
  """
  Detects outliers in a dataset using the Interquartile Range (IQR) method.

  Args:
    data: A pandas Series or NumPy array.

  Returns:
    A list of outlier values.
  """
  Q1 = data.quantile(0.25)
  Q3 = data.quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outliers = data[(data < lower_bound) | (data > upper_bound)]
  return outliers.values.tolist()


# Create a dictionary to store outlier information
outlier_summary = {}

# Iterate through each numerical column in the DataFrame
for column in df.select_dtypes(include=['number']).columns:
  # Detect outliers using the IQR method
  outliers = detect_outliers_iqr(df[column])

  # Store outlier information in the dictionary
  outlier_summary[column] = {
      "count": len(outliers),
      "values": outliers
  }

  # Create a boxplot to visualize outliers
  plt.figure(figsize=(4, 3))  # Adjust figure size as needed
  sns.boxplot(x=df[column])
  plt.title(f'Boxplot of {column}')
  plt.show()

  # Create a histogram to visualize outliers
  plt.figure(figsize=(4, 3))  # Adjust figure size as needed
  sns.histplot(df[column], kde=True)
  plt.title(f'Histogram of {column}')
  plt.show()


# Print the summary of outliers
print("Summary of outliers:")
for column, info in outlier_summary.items():
  print(f"{column}:")
  print(f"  Number of outliers: {info['count']}")
  print(f"  Outlier values: {info['values']}")


# Get user input on which outliers to remove
print("\nDo you want to remove any outliers?")
print("1. Remove all outliers")
print("2. Remove specific outliers (enter column names separated by commas)")
print("3. Do not remove any outliers")
choice = input("Enter your choice (1, 2, or 3): ")

if choice == "1":
  # Remove all outliers
  for column in outlier_summary:
    if outlier_summary[column]["count"] > 0:
      # Get indices of outliers
      outlier_indices = df[df[column].isin(outlier_summary[column]["values"])].index
      # Drop rows containing outliers
      df.drop(outlier_indices, inplace=True)
  print("All outliers removed.")

elif choice == "2":
  # Remove specific outliers
  columns_to_remove = input("Enter column names separated by commas: ").split(",")
  for column in columns_to_remove:
    column = column.strip()  # Remove leading/trailing whitespace
    if column in outlier_summary and outlier_summary[column]["count"] > 0:
      # Get indices of outliers
      outlier_indices = df[df[column].isin(outlier_summary[column]["values"])].index
      # Drop rows containing outliers
      df.drop(outlier_indices, inplace=True)
  print("Specific outliers removed.")

elif choice == "3":
  print("No outliers removed.")
else:
  print("Invalid choice.")

# Overview summary
print("\nOverview Summary:")
print("Outliers detected and handled.")
print("Method used to remove outliers: IQR method.")
print("Note: Outlier removal can affect data distribution. Carefully consider the impact on your analysis.")
# Out:
# Summary of outliers:
# Ratio of CH4 in Feed:
#   Number of outliers: 0
#   Outlier values: []
# Reaction Temperature:
#   Number of outliers: 29
#   Outlier values: [400, 400, 400, 400, 450, 450, 400, 400, 400, 400, 450, 450, 450, 450, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 1000, 1000, 1000, 1000, 1000]
# Ni Loading:
#   Number of outliers: 156
#   Outlier values: [22.2, 27.9, 30.8, 23.1, 18.2, 23.1, 18.2, 23.1, 18.2, 18.2, 18.2, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 23.0, 20.0, 25.0, 20.0, 20.0, 20.2, 32.0, 51.1, 20.2, 32.0, 19.7, 19.7, 20.0, 40.0, 60.0, 26.9, 27.9, 20.0, 20.0, 20.0, 20.0, 20.0, 30.1, 30.1, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 25.0, 23.0, 23.0, 20.0, 20.0, 18.5, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 18.9, 19.6, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 29.5, 18.6, 18.6, 18.6, 18.6, 18.6, 25.0, 20.0]
# Reaction Time:
#   Number of outliers: 102
#   Outlier values: [120.0, 120.0, 120.0, 120.0, 60.0, 60.0, 60.0, 60.0, 72.0, 60.0, 60.0, 80.0, 80.0, 100.0, 96.0, 96.0, 100.0, 100.0, 72.0, 72.0, 60.0, 60.0, 80.0, 100.0, 72.0, 75.0, 75.0, 75.0, 75.0, 75.0, 100.0, 100.0, 100.0, 100.0, 100.0, 75.0, 120.0, 80.0, 80.0, 80.0, 80.0, 120.0, 200.0, 100.0, 100.0, 100.0, 60.0, 80.0, 80.0, 120.0, 60.0, 60.0, 60.0, 60.0, 60.0, 80.0, 80.0, 80.0, 80.0, 80.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 75.0, 75.0, 100.0, 100.0, 75.0, 75.0, 60.0, 60.0, 80.0, 80.0, 100.0, 100.0, 80.0, 80.0, 65.0, 65.0, 65.0, 65.0, 80.0, 60.0, 80.0, 100.0, 60.0, 80.0, 100.0, 75.0, 100.0, 72.0, 72.0, 72.0, 72.0, 72.0, 72.0, 72.0]
# Pore Size:
#   Number of outliers: 88
#   Outlier values: [30.1, 31.9, 30.1, 31.9, 30.1, 31.9, 30.1, 31.9, 30.1, 31.9, 30.1, 31.9, 39.3, 38.0, 38.0, 38.0, 37.0, 34.0, 37.0, 34.0, 69.3, 40.3, 69.3, 40.3, 35.9, 35.9, 28.19, 39.0, 37.0, 40.0, 41.0, 74.0, 38.7, 74.0, 38.7, 74.0, 38.7, 74.0, 38.7, 74.0, 38.7, 28.65, 28.65, 36.81, 41.87, 46.13, 29.8, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 35.0, 37.0, 37.0, 35.0, 37.0, 37.0, 28.0, 28.89, 36.0, 30.0, 49.0, 30.5, 30.5, 30.5, 30.5, 55.1, 55.1, 55.1, 55.1, 42.71, 49.39, 35.76, 46.27, 29.8, 31.5, 32.6, 34.4, 29.82, 35.3, 167.0, 127.0, 100.0, 81.0]
# Pore Volume:
#   Number of outliers: 25
#   Outlier values: [1.33, 1.68, 1.33, 1.68, 1.71, 1.71, 1.9, 1.6, 2.9, 1.7, 1.7, 1.7, 1.7, 1.7, 1.7, 1.6, 1.2, 1.143, 1.143, 1.143, 1.143, 1.143, 1.56, 1.46, 1.66]
# Surface Area:
#   Number of outliers: 144
#   Outlier values: [599.0, 516.0, 506.9, 506.9, 540.2, 500.9, 540.2, 500.9, 540.2, 500.9, 540.2, 500.9, 672.0, 643.0, 621.0, 672.0, 643.0, 621.0, 597.0, 515.0, 597.0, 515.0, 597.0, 676.0, 600.0, 508.0, 636.0, 676.0, 600.0, 508.0, 636.0, 509.7, 509.7, 516.3, 516.3, 528.6, 528.6, 510.0, 799.0, 510.0, 799.0, 550.0, 550.0, 519.0, 675.0, 693.0, 675.0, 693.0, 675.0, 693.0, 500.0, 520.0, 520.0, 481.0, 500.0, 520.0, 520.0, 481.0, 810.2, 747.4, 747.4, 542.9, 747.4, 661.0, 661.0, 583.2, 584.0, 582.8, 583.875, 587.1, 713.0, 713.0, 593.2, 481.9, 540.2, 540.2, 540.2, 1062.0, 831.0, 778.0, 1062.0, 831.0, 778.0, 1062.0, 831.0, 778.0, 1062.0, 831.0, 778.0, 1062.0, 831.0, 778.0, 1062.0, 831.0, 778.0, 538.7, 580.0, 566.0, 898.0, 983.0, 620.0, 594.0, 509.0, 490.0, 627.0, 567.8, 567.8, 567.8, 567.8, 567.8, 511.0, 511.0, 511.0, 511.0, 511.0, 579.0, 579.0, 579.0, 552.0, 552.0, 552.0, 552.0, 663.0, 511.0, 570.0, 563.0, 574.0, 558.2, 558.2, 558.2, 558.2, 504.0, 484.0, 941.0, 885.0, 512.0, 661.0, 536.0, 692.0, 766.0, 710.0, 710.0, 625.0, 500.0]
# H2-TPR Peak Temperature:
#   Number of outliers: 0
#   Outlier values: []
# Ni Particle Size:
#   Number of outliers: 88
#   Outlier values: [78.0, 78.0, 38.0, 38.0, 38.2, 30.0, 34.7, 28.0, 29.0, 28.0, 35.9, 34.5, 28.0, 29.0, 28.0, 35.9, 34.5, 40.2, 40.2, 29.0, 29.0, 29.0, 28.0, 42.7, 42.7, 42.7, 35.6, 28.7, 28.7, 38.4, 38.4, 48.6, 30.0, 30.0, 32.0, 32.0, 32.0, 32.0, 30.52, 31.88, 32.0, 32.0, 57.0, 49.0, 49.0, 49.0, 55.0, 85.0, 85.0, 51.63, 52.95, 49.0, 38.0, 42.0, 49.0, 38.0, 42.0, 29.4, 29.4, 32.1, 47.7, 31.3, 31.3, 31.5, 36.7, 38.0, 31.0, 32.5, 34.8, 30.1, 28.7, 28.7, 28.7, 28.7, 28.7, 28.7, 28.7, 28.9, 34.0, 42.0, 34.0, 34.0, 34.0, 34.0, 54.3, 31.2, 49.9, 71.1]
# Ni Dispersion:
#   Number of outliers: 658
#   Outlier values: [15.9, 15.3, 13.2, 9.3, 15.9, 15.3, 13.2, 9.3, 12.0, 8.4, 6.9, 7.2, 5.8, 4.8, 2.6, 4.8, 2.6, 3.7, 3.4, 2.8, 3.7, 3.4, 2.8, 4.6, 3.4, 4.5, 6.4, 6.4, 18.5, 21.9, 17.8, 13.6, 16.5, 13.6, 17.8, 13.6, 16.5, 13.6, 22.8, 22.8, 42.2, 42.2, 45.6, 45.2, 42.2, 13.1, 12.3, 12.8, 8.2, 12.6, 13.1, 12.3, 12.8, 8.2, 12.6, 22.93, 22.93, 13.0, 12.2, 12.2, 10.1, 10.1, 9.4, 9.4, 7.3, 7.3, 12.2, 12.2, 10.1, 10.1, 1.2, 0.7, 0.7, 1.1, 1.2, 0.7, 0.7, 1.1, 0.7, 4.9, 8.4, 7.0, 4.2, 4.9, 8.4, 7.0, 4.2, 4.9, 8.4, 7.0, 4.2, 4.9, 8.4, 7.0, 4.2, 4.9, 8.4, 7.0, 13.3, 16.3, 13.3, 16.3, 13.3, 16.3, 16.3, 16.3, 13.8, 12.7, 12.1, 21.6, 13.8, 12.7, 12.1, 21.6, 37.0, 0.5, 37.0, 0.5, 37.0, 0.5, 37.0, 0.5, 4.3, 4.5, 4.6, 5.2, 4.3, 4.5, 4.6, 5.2, 5.2, 24.9, 18.5, 22.4, 24.9, 18.5, 22.4, 8.9, 8.6, 10.2, 6.9, 6.1, 8.0, 6.1, 8.0, 6.1, 8.0, 9.4, 9.4, 15.6, 15.6, 18.5, 18.5, 20.5, 20.5, 15.8, 10.43, 10.68, 15.8, 10.43, 10.68, 15.8, 10.43, 10.68, 15.8, 10.43, 10.68, 14.3, 10.0, 14.8, 19.4, 14.3, 10.0, 14.8, 19.4, 18.2, 17.1, 19.7, 19.1, 11.8, 18.2, 17.1, 19.7, 19.1, 11.8, 1.2, 1.3, 5.4, 1.2, 1.3, 5.4, 10.4, 10.4, 10.4, 13.6, 13.6, 13.6, 13.6, 10.1, 10.1, 11.3, 11.3, 8.6, 8.6, 2.6, 2.6, 0.55, 1.2, 2.8, 2.8, 2.6, 2.6, 2.6, 2.6, 5.58, 5.58, 5.58, 5.58, 3.7, 3.7, 3.4, 3.4, 0.54, 0.54, 0.5, 0.5, 9.6, 9.6, 7.8, 7.8, 12.3, 10.6, 10.3, 12.3, 12.3, 12.3, 3.0, 3.0, 5.0, 2.0, 1.0, 1.0, 2.0, 10.0, 12.1, 16.4, 10.0, 12.1, 16.4, 10.0, 12.1, 16.4, 15.9, 12.9, 15.9, 12.9, 15.9, 12.9, 15.9, 12.9, 15.9, 12.9, 12.0, 3.7, 3.7, 1.4, 4.8, 12.0, 3.7, 3.7, 1.4, 4.8, 1.38, 0.16, 0.62, 1.57, 0.16, 1.38, 6.3, 6.8, 7.8, 8.9, 8.6, 2.0, 3.0, 8.0, 2.0, 11.0, 7.0, 5.0, 2.0, 3.0, 8.0, 2.0, 11.0, 7.0, 5.0, 7.0, 26.3, 37.1, 26.3, 37.1, 8.07, 14.2, 21.2, 6.99, 2.45, 2.98, 3.06, 3.14, 3.025, 2.91, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 3.14, 6.0, 10.0, 10.0, 15.5, 10.0, 15.5, 10.0, 15.5, 15.5, 15.5, 7.8, 9.5, 8.6, 8.9, 10.7, 3.7, 5.2, 3.6, 8.5, 4.3, 3.7, 5.2, 3.6, 8.5, 4.3, 3.7, 5.2, 3.6, 8.5, 4.3, 3.7, 5.2, 3.6, 8.5, 4.3, 3.7, 5.2, 3.6, 8.5, 4.3, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 11.5, 8.9, 11.5, 10.2, 11.6, 9.3, 16.2, 4.37, 8.32, 6.85, 0.77, 15.3, 7.55, 5.84, 2.12, 8.4, 8.4, 8.4, 8.4, 8.4, 8.4, 10.9, 10.9, 10.9, 10.9, 10.9, 10.9, 10.9, 10.9, 10.9, 10.9, 7.5, 7.5, 7.5, 7.5, 7.5, 9.5, 9.5, 9.5, 9.5, 9.5, 11.5, 11.5, 11.4, 9.6, 9.5, 6.7, 5.7, 5.7, 5.7, 5.7, 5.7, 5.7, 25.5, 25.5, 25.5, 25.5, 25.5, 25.5, 27.5, 47.8, 32.1, 32.1, 32.1, 12.3, 12.3, 12.3, 12.3, 4.62, 6.64, 8.92, 10.87, 8.1, 3.83, 8.0, 8.64, 1.3, 3.2, 4.3, 2.6, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 9.8, 10.0, 11.1, 8.9, 7.8, 10.0, 25.2, 21.7, 25.2, 21.7, 7.1, 4.91, 4.59, 4.33, 4.91, 4.59, 4.33, 4.91, 4.59, 4.33, 4.91, 4.59, 4.33, 18.2, 12.9, 8.1, 18.2, 12.9, 8.1, 6.54, 6.76, 9.66, 8.7, 8.7, 8.7, 8.7, 8.7, 3.1, 3.1, 3.1, 3.1, 3.1, 9.1, 9.1, 9.1, 9.1, 9.1, 8.3, 8.3, 8.3, 8.3, 8.3, 9.2, 9.2, 9.2, 9.2, 9.2, 10.0, 10.0, 10.0, 10.0, 10.0, 14.1, 7.8, 19.0, 10.2, 10.2, 10.2, 10.2, 10.2, 13.8, 13.8, 13.8, 13.8, 13.8, 1.3, 3.3, 77.0, 43.0, 69.0, 6.8, 7.0, 5.5, 4.8, 6.6, 6.2, 7.0, 2.9, 5.9, 11.4, 2.9, 5.9, 11.4, 2.9, 5.9, 11.4, 2.9, 5.9, 11.4, 2.9, 5.9, 11.4, 2.0, 0.5, 3.5, 3.5, 3.5, 3.5, 3.5, 6.5, 6.5, 6.5, 6.5, 6.5, 6.2, 6.2, 6.2, 6.2, 6.2, 3.5, 3.5, 6.7, 6.1, 5.8, 4.7, 24.8, 16.3, 13.1, 9.6, 7.2, 13.1, 9.6, 4.7, 13.1, 9.6, 4.7, 9.1, 8.7, 7.1, 4.8, 7.08, 7.52, 8.2, 6.41, 9.05, 11.84, 10.7, 21.3, 13.2, 2.03, 5.03, 1.42]
# Modifier Electronegativity:
#   Number of outliers: 0
#   Outlier values: []
# GHSV:
#   Number of outliers: 122
#   Outlier values: [216000, 216000, 216000, 200000, 200000, 200000, 200000, 150000, 240000, 240000, 240000, 240000, 240000, 240000, 200000, 200000, 200000, 200000, 200000, 200000, 200000, 200000, 200000, 192000, 192000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 144000, 192000, 192000, 192000, 192000, 192000, 192000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 180000, 270000, 270000, 270000, 960000, 960000, 300000, 275000, 275000, 275000, 275000, 275000, 275000, 275000, 150000, 150000, 150000, 150000, 150000, 150000, 150000, 150000, 275000, 275000, 275000, 150000, 150000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 240000, 180000, 180000, 180000, 180000, 180000, 180000, 158000, 158000, 300000, 300000, 300000, 300000, 300000, 1440000, 1440000, 1440000, 125000, 125000]
# CH4 Conversion:
#   Number of outliers: 0
#   Outlier values: []
# CO2 Conversion:
#   Number of outliers: 24
#   Outlier values: [3.185, 0.51, 4.06, 2.0, 3.0, 2.0, 3.9, 6.1, 2.571, 5.905, 5.0, 4.0, 2.0, 4.0, 5.0, 4.02, 7.33, 0.0, 0.39, 0.88, 0.64, 0.44, 0.77, 5.0]
# Syngas_Ratio:
#   Number of outliers: 113
#   Outlier values: [0.45, 1.276, 1.284, 0.25, 0.41, 0.438, 0.434, 0.206, 0.165, 0.312, 0.454, 0.454, 0.364, 0.0, 0.0, 0.35, 0.456, 0.35, 0.4, 0.41, 0.42, 0.35, 0.385, 0.4, 0.375, 0.313, 0.34, 0.38, 1.46, 1.61, 0.222, 0.395, 0.216, 0.378, 0.265, 0.443, 0.265, 0.443, 0.3, 0.303, 0.358, 0.332, 0.406, 0.398, 0.346, 0.4, 0.42, 0.446, 1.29, 1.5, 1.262, 1.28, 0.4, 1.25, 1.32, 1.33, 1.25, 1.3, 1.24, 1.24, 0.45, 1.26, 1.28, 1.36, 1.24, 1.256, 0.41, 0.44, 0.34, 0.39, 0.29, 1.25, 1.25, 0.43, 0.38, 0.39, 0.39, 1.25, 0.4, 0.4, 1.24, 1.28, 0.37, 0.42, 0.12, 0.25, 1.25, 1.24, 1.38, 1.62, 0.0, 0.11, 0.35, 0.0, 0.3, 0.39, 0.27, 0.33, 0.34, 0.0, 0.15, 0.42, 0.44, 0.4, 0.28, 0.36, 0.38, 0.33, 0.32, 0.41, 0.35, 0.01, 0.46]
#
# Do you want to remove any outliers?
# 1. Remove all outliers
# 2. Remove specific outliers (enter column names separated by commas)
# 3. Do not remove any outliers
# Enter your choice (1, 2, or 3): 1
# All outliers removed.
#
# Overview Summary:
# Outliers detected and handled.
# Method used to remove outliers: IQR method.
# Note: Outlier removal can affect data distribution. Carefully consider the impact on your analysis.

# %% [markdown]
# Step 4: Summary Statistics

# %%
# Calculate summary statistics for numerical columns
numeric_summary = df.describe()

# Display the summary statistics table
print("\nSummary Statistics for Numerical Columns:\n", numeric_summary)

# Calculate the IQR for each numerical column
iqr_values = {}
for column in df.select_dtypes(include=['number']).columns:
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  iqr_values[column] = IQR

# Print the IQR values
print("\nInterquartile Range (IQR) for Numerical Columns:\n", iqr_values)

# Analyze data distribution and identify skews or patterns
for column in df.select_dtypes(include=['number']).columns:
  mean = df[column].mean()
  median = df[column].median()
  std_dev = df[column].std()

  print(f"\nAnalyzing '{column}':")
  print(f"  Mean: {mean:.2f}")
  print(f"  Median: {median:.2f}")
  print(f"  Standard Deviation: {std_dev:.2f}")

  if mean > median:
    print("  Distribution is right-skewed (positively skewed).")
  elif mean < median:
    print("  Distribution is left-skewed (negatively skewed).")
  else:
    print("  Distribution is approximately symmetrical.")

  # Add further analysis based on specific needs, e.g., histograms, boxplots
  # ...
# Out:
# Summary Statistics for Numerical Columns:
#         Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  Reaction Time  \
# count            659.000000            659.000000  659.000000     659.000000
# mean               0.365117            709.104704    8.141407      12.396564
# std                0.154220             78.069136    3.575561      14.569877
# min                0.050000            500.000000    0.500000       0.100000
# 25%                0.250000            700.000000    5.000000       0.500000
# 50%                0.450000            700.000000    9.000000       7.000000
# 75%                0.500000            750.000000   10.000000      20.000000
# max                0.500000            900.000000   17.600000      50.000000
#
#         Pore Size  Pore Volume  Surface Area  H2-TPR Peak Temperature  \
# count  659.000000   659.000000    659.000000               659.000000
# mean    10.665200     0.344349    145.644033               624.308240
# std      6.357232     0.210861    102.248336               170.059029
# min      0.500000     0.020000      4.000000               231.000000
# 25%      6.350000     0.190000     59.500000               467.500000
# 50%      8.900000     0.330000    138.000000               655.000000
# 75%     13.700000     0.470000    192.250000               780.000000
# max     27.420000     1.040000    476.000000               994.000000
#
#        Ni Particle Size  Ni Dispersion  Modifier Electronegativity  \
# count        659.000000     659.000000                  659.000000
# mean          10.187527       9.886117                    0.413162
# std            5.567211       0.000000                    0.663830
# min            1.400000       9.886117                    0.000000
# 25%            6.000000       9.886117                    0.000000
# 50%            9.000000       9.886117                    0.000000
# 75%           13.500000       9.886117                    1.100000
# max           27.100000       9.886117                    2.200000
#
#                 GHSV  CH4 Conversion  CO2 Conversion  Syngas_Ratio
# count     659.000000      659.000000      659.000000    659.000000
# mean    36554.172989       64.082939       71.524132      0.869879
# std     25991.513579       22.438710       19.014726      0.135734
# min      1700.000000        7.600000        9.510000      0.470000
# 25%     18000.000000       49.565000       61.175000      0.790000
# 50%     30000.000000       65.720000       74.000000      0.880000
# 75%     60000.000000       82.987500       86.850000      0.960000
# max    120000.000000       98.870000       98.700000      1.220000
#
# Interquartile Range (IQR) for Numerical Columns:
#  {'Ratio of CH4 in Feed': 0.25, 'Reaction Temperature': 50.0, 'Ni Loading': 5.0, 'Reaction Time': 19.5, 'Pore Size': 7.35, 'Pore Volume': 0.27999999999999997, 'Surface Area': 132.75, 'H2-TPR Peak Temperature': 312.5, 'Ni Particle Size': 7.5, 'Ni Dispersion': 0.0, 'Modifier Electronegativity': 1.1, 'GHSV': 42000.0, 'CH4 Conversion': 33.4225, 'CO2 Conversion': 25.674999999999997, 'Syngas_Ratio': 0.16999999999999993}
#
# Analyzing 'Ratio of CH4 in Feed':
#   Mean: 0.37
#   Median: 0.45
#   Standard Deviation: 0.15
#   Distribution is left-skewed (negatively skewed).
#
# Analyzing 'Reaction Temperature':
#   Mean: 709.10
#   Median: 700.00
#   Standard Deviation: 78.07
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'Ni Loading':
#   Mean: 8.14
#   Median: 9.00
#   Standard Deviation: 3.58
#   Distribution is left-skewed (negatively skewed).
#
# Analyzing 'Reaction Time':
#   Mean: 12.40
#   Median: 7.00
#   Standard Deviation: 14.57
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'Pore Size':
#   Mean: 10.67
#   Median: 8.90
#   Standard Deviation: 6.36
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'Pore Volume':
#   Mean: 0.34
#   Median: 0.33
#   Standard Deviation: 0.21
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'Surface Area':
#   Mean: 145.64
#   Median: 138.00
#   Standard Deviation: 102.25
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'H2-TPR Peak Temperature':
#   Mean: 624.31
#   Median: 655.00
#   Standard Deviation: 170.06
#   Distribution is left-skewed (negatively skewed).
#
# Analyzing 'Ni Particle Size':
#   Mean: 10.19
#   Median: 9.00
#   Standard Deviation: 5.57
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'Ni Dispersion':
#   Mean: 9.89
#   Median: 9.89
#   Standard Deviation: 0.00
#   Distribution is approximately symmetrical.
#
# Analyzing 'Modifier Electronegativity':
#   Mean: 0.41
#   Median: 0.00
#   Standard Deviation: 0.66
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'GHSV':
#   Mean: 36554.17
#   Median: 30000.00
#   Standard Deviation: 25991.51
#   Distribution is right-skewed (positively skewed).
#
# Analyzing 'CH4 Conversion':
#   Mean: 64.08
#   Median: 65.72
#   Standard Deviation: 22.44
#   Distribution is left-skewed (negatively skewed).
#
# Analyzing 'CO2 Conversion':
#   Mean: 71.52
#   Median: 74.00
#   Standard Deviation: 19.01
#   Distribution is left-skewed (negatively skewed).
#
# Analyzing 'Syngas_Ratio':
#   Mean: 0.87
#   Median: 0.88
#   Standard Deviation: 0.14
#   Distribution is left-skewed (negatively skewed).

# %% [markdown]
# Step 5: One-Hot Encoding for Categorical Variables

# %%
import pandas as pd
# Identify categorical variables
categorical_columns = df.select_dtypes(include=['object']).columns

# Display the list of categorical variables to the user
print("Categorical variables found in the dataset:")
print(categorical_columns)

# Confirm data types to avoid misinterpreting numerical data as categorical
print("\nData types of each column:")
print(df.dtypes)

# Explain the purpose of one-hot encoding
print("\nOne-hot encoding is used to convert categorical variables into numerical format suitable for analysis.")
print("This involves creating new binary columns for each unique category in the original column.")
print("This allows machine learning algorithms to understand and utilize categorical data effectively.")

# Apply one-hot encoding
df_encoded = pd.get_dummies(df, columns=categorical_columns)

# Display the updated DataFrame with encoded columns
print("\nDataFrame after one-hot encoding:")
print(df_encoded.head())

# Explain the changes to the dataset
print("\nThe dataset has been transformed by adding new columns for each category.")
print("Original categorical columns have been replaced with numerical representations.")
print("This allows for better analysis and model building.")
# Out:
# Categorical variables found in the dataset:
# Index(['Catalyst'], dtype='object')
#
# Data types of each column:
# Catalyst                       object
# Ratio of CH4 in Feed          float64
# Reaction Temperature            int64
# Ni Loading                    float64
# Reaction Time                 float64
# Pore Size                     float64
# Pore Volume                   float64
# Surface Area                  float64
# H2-TPR Peak Temperature       float64
# Ni Particle Size              float64
# Ni Dispersion                 float64
# Modifier Electronegativity    float64
# GHSV                            int64
# CH4 Conversion                float64
# CO2 Conversion                float64
# Syngas_Ratio                  float64
# dtype: object
#
# One-hot encoding is used to convert categorical variables into numerical format suitable for analysis.
# This involves creating new binary columns for each unique category in the original column.
# This allows machine learning algorithms to understand and utilize categorical data effectively.
#
# DataFrame after one-hot encoding:
#    Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  Reaction Time  \
# 0                  0.15                   650        10.0          0.500
# 1                  0.15                   650        10.0          0.500
# 2                  0.15                   650        10.0          0.500
# 3                  0.15                   650        10.0          0.500
# 5                  0.15                   800         5.0          4.167
#
#    Pore Size  Pore Volume  Surface Area  H2-TPR Peak Temperature  \
# 0        4.7         0.58         476.0                    640.0
# 1        4.7         0.58         476.0                    640.0
# 2        5.2         0.58         455.0                    457.0
# 3        5.2         0.58         455.0                    457.0
# 5       20.9         0.62         128.7                    782.0
#
#    Ni Particle Size  Ni Dispersion  ...  Catalyst_Sn0.04 Ni/Al  Catalyst_TAL0  \
# 0               2.9       9.886117  ...                  False          False
# 1               4.6       9.886117  ...                  False          False
# 2               2.9       9.886117  ...                  False          False
# 3               4.6       9.886117  ...                  False          False
# 5               6.2       9.886117  ...                  False          False
#
#    Catalyst_TAL100  Catalyst_TAL25  Catalyst_TAL50  Catalyst_TAL75  \
# 0            False           False           False           False
# 1            False           False           False           False
# 2            False           False           False           False
# 3            False           False           False           False
# 5            False           False           False           False
#
#    Catalyst_UNAU  Catalyst_Zr (10)-Ni(15)/ perlite  \
# 0          False                             False
# 1          False                             False
# 2          False                             False
# 3          False                             False
# 5          False                             False
#
#    Catalyst_Zr (20)-Ni(15)/perlite,  Catalyst_–Ni–La2O3
# 0                             False               False
# 1                             False               False
# 2                             False               False
# 3                             False               False
# 5                             False               False
#
# [5 rows x 330 columns]
#
# The dataset has been transformed by adding new columns for each category.
# Original categorical columns have been replaced with numerical representations.
# This allows for better analysis and model building.

# %% [markdown]
# Step 6: Checking for redundant columns

# %%
# Identify columns with constant values
constant_columns = [col for col in df_encoded.columns if df_encoded[col].nunique() <= 1]

# Print columns with constant values
if constant_columns:
  print("\nColumns with constant values:")
  print(constant_columns)
  print("These columns provide no information for analysis and can be removed.")
else:
  print("\nNo columns with constant values found.")

# Identify columns with duplicate information
duplicate_columns = []
for i in range(len(df_encoded.columns)):
  for j in range(i + 1, len(df_encoded.columns)):
    if df_encoded.iloc[:, i].equals(df_encoded.iloc[:, j]):
      duplicate_columns.append((df_encoded.columns[i], df_encoded.columns[j]))

# Print columns with duplicate information
if duplicate_columns:
  print("\nColumns with duplicate information:")
  for col1, col2 in duplicate_columns:
    print(f"Columns '{col1}' and '{col2}' have identical values.")
  print("These columns contain redundant information and one of them can be removed.")
else:
  print("\nNo columns with duplicate information found.")

# Identify irrelevant columns (this requires domain knowledge)
# This is a placeholder for a more sophisticated method
irrelevant_columns = []  # This list would be populated based on domain knowledge
# Example: irrelevant_columns = ['column_name1', 'column_name2']

# Print irrelevant columns
if irrelevant_columns:
  print("\nIrrelevant columns:")
  print(irrelevant_columns)
  print("These columns are not relevant to the analysis and can be removed.")
else:
  print("\nNo irrelevant columns identified (requires domain knowledge).")

# Ask user if they want to remove redundant columns
print("\nDo you want to remove any redundant columns?")
print("1. Remove all redundant columns")
print("2. Remove specific columns (enter column names separated by commas)")
print("3. Do not remove any columns")
choice = input("Enter your choice (1, 2, or 3): ")

if choice == "1":
  # Remove all redundant columns
  columns_to_remove = constant_columns + [col1 for col1, col2 in duplicate_columns] + irrelevant_columns
  df_encoded.drop(columns=columns_to_remove, inplace=True)
  print("All redundant columns removed.")

elif choice == "2":
  # Remove specific columns
  columns_to_remove = input("Enter column names separated by commas: ").split(",")
  for column in columns_to_remove:
    column = column.strip()  # Remove leading/trailing whitespace
    if column in df_encoded.columns:
      df_encoded.drop(columns=column, inplace=True)
  print("Specific columns removed.")

elif choice == "3":
  print("No redundant columns removed.")
else:
  print("Invalid choice.")

# Summary
print("\nOverview Summary:")
print("Redundant columns identified and handled.")
print("Methods used to identify redundancies:")
print("- Columns with constant values")
print("- Columns with duplicate information")
print("- Irrelevant columns (requires domain knowledge)")
print("Note: Removing redundant columns can improve data efficiency and analysis.")
# Out:
# Columns with constant values:
# ['Ni Dispersion']
# These columns provide no information for analysis and can be removed.
#
# No columns with duplicate information found.
#
# No irrelevant columns identified (requires domain knowledge).
#
# Do you want to remove any redundant columns?
# 1. Remove all redundant columns
# 2. Remove specific columns (enter column names separated by commas)
# 3. Do not remove any columns
# Enter your choice (1, 2, or 3): 1
# All redundant columns removed.
#
# Overview Summary:
# Redundant columns identified and handled.
# Methods used to identify redundancies:
# - Columns with constant values
# - Columns with duplicate information
# - Irrelevant columns (requires domain knowledge)
# Note: Removing redundant columns can improve data efficiency and analysis.

# %% [markdown]
# Step 7: Visualizations - General

# %%
# prompt: Create visualizations (scatter plots, histograms, box plots) to identify trends and relationships between variables, be able to copy to anoother data set to use the same code for analysis

import matplotlib.pyplot as plt
# Step 8: Visualizing Data Relationships

# Function to create scatter plots for pairs of variables
def create_scatter_plots(df, variable_pairs):
  """
  Creates scatter plots to visualize relationships between pairs of variables.

  Args:
    df: The pandas DataFrame containing the data.
    variable_pairs: A list of tuples, where each tuple contains two variable names.
  """
  for var1, var2 in variable_pairs:
    plt.figure(figsize=(6, 4))  # Adjust figure size as needed
    plt.scatter(df[var1], df[var2])
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.title(f"Scatter Plot: {var1} vs. {var2}")
    plt.show()

# Function to create histograms for individual variables
def create_histograms(df, variables):
  """
  Creates histograms to visualize the distribution of individual variables.

  Args:
    df: The pandas DataFrame containing the data.
    variables: A list of variable names.
  """
  for variable in variables:
    plt.figure(figsize=(6, 4))  # Adjust figure size as needed
    plt.hist(df[variable], bins=10)  # You can adjust the number of bins
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title(f"Histogram of {variable}")
    plt.show()

# Function to create box plots for individual variables
def create_box_plots(df, variables):
  """
  Creates box plots to visualize the distribution and potential outliers of individual variables.

  Args:
    df: The pandas DataFrame containing the data.
    variables: A list of variable names.
  """
  for variable in variables:
    plt.figure(figsize=(6, 4))  # Adjust figure size as needed
    sns.boxplot(x=df[variable])
    plt.xlabel(variable)
    plt.title(f"Box Plot of {variable}")
    plt.show()

# Select the variables you want to visualize relationships between
# Replace with your actual variable names
variables_for_scatter = [('Reaction Time', 'Ratio of CH4 in Feed'), ('CH4 Conversion', 'CO2 Conversion')]

# Select the variables for histograms and box plots
variables_for_histograms = ['CH4 Conversion', 'CO2 Conversion','Syngas_Ratio']
variables_for_boxplots = ['CH4 Conversion', 'CO2 Conversion','Syngas_Ratio']


# Create visualizations
create_scatter_plots(df_encoded, variables_for_scatter)
create_histograms(df_encoded, variables_for_histograms)
create_box_plots(df_encoded, variables_for_boxplots)

# Now you can copy this code and paste it in a notebook for a new dataset.
# Remember to replace the DataFrame name 'df_encoded' and adjust the variable names as needed.

print("\nVisualizations created to identify trends and relationships between variables.")
# Out:
# Visualizations created to identify trends and relationships between variables.

# %% [markdown]
# Step 8: Visualizing Data Relationship Based on Correlation Values

# %%
import matplotlib.pyplot as plt
# Identify numerical and categorical variables
numerical_columns = df_encoded.select_dtypes(include=['number']).columns
categorical_columns = df_encoded.select_dtypes(include=['object']).columns

# Create a table with relationships between variables
print("\nRelationships between variables (order of magnitude):")
relationships = []
for i in range(len(df_encoded.columns)):
  for j in range(i + 1, len(df_encoded.columns)):
    col1 = df_encoded.columns[i]
    col2 = df_encoded.columns[j]
    correlation = df_encoded[col1].corr(df_encoded[col2])
    relationships.append((col1, col2, abs(correlation)))

# Sort relationships by correlation strength
relationships.sort(key=lambda x: x[2], reverse=True)

# Display the relationships in a numbered table
print("Relationships between Variables (Top 1000):")
for i, (col1, col2, correlation) in enumerate(relationships[:1000]):
  print(f"{i+1}. {col1} & {col2}: {correlation:.4f}")

# Get user input for visualization range
print("\nWhich relationships do you want to visualize?")
start_range = int(input("Enter the starting number: "))
end_range = int(input("Enter the ending number: "))

# Visualize selected relationships
for i in range(start_range - 1, end_range):
  col1, col2, correlation = relationships[i]
  print(f"\nVisualizing relationship between {col1} and {col2}:")

  if col1 in numerical_columns and col2 in numerical_columns:
    # Scatter plot for continuous variables
    plt.figure(figsize=(6, 4))
    sns.regplot(x=df_encoded[col1], y=df_encoded[col2], line_kws={'color': 'red'})
    plt.title(f"{col1} vs {col2}")
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.show()

  elif col1 in categorical_columns and col2 in categorical_columns:
    # Bar/count plot for categorical variables
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df_encoded[col1], hue=df_encoded[col2])
    plt.title(f"{col1} vs {col2}")
    plt.xlabel(col1)
    plt.ylabel("Count")
    plt.show()

  else:
    # Pair plot to show relationships across multiple features
    # (if identified)
    # Example: sns.pairplot(df_encoded[['col1', 'col2', 'col3']])
    print("Consider using pair plot for relationships across multiple features.")

# Explain relationships and patterns
print("\nBased on the visualizations and correlation analysis:")
for i in range(start_range - 1, end_range):
  col1, col2, correlation = relationships[i]
  if correlation > 0.7:
    print(f"  - A strong positive correlation exists between {col1} and {col2}.")
    print(f"    As {col1} increases, {col2} tends to increase as well.")
  elif correlation < -0.7:
    print(f"  - A strong negative correlation exists between {col1} and {col2}.")
    print(f"    As {col1} increases, {col2} tends to decrease.")
  else:
    print(f"  - The relationship between {col1} and {col2} is moderate or weak.")
# Out:
# Relationships between variables (order of magnitude):
# Relationships between Variables (Top 1000):
# 1. CH4 Conversion & CO2 Conversion: 0.9029
# 2. Reaction Temperature & CH4 Conversion: 0.6542
# 3. Reaction Temperature & CO2 Conversion: 0.6379
# 4. Pore Volume & Surface Area: 0.6155
# 5. CO2 Conversion & Syngas_Ratio: 0.5448
# 6. CH4 Conversion & Syngas_Ratio: 0.5214
# 7. Pore Size & Surface Area: 0.4302
# 8. GHSV & Syngas_Ratio: 0.3390
# 9. Surface Area & Ni Particle Size: 0.3025
# 10. Pore Volume & Ni Particle Size: 0.2915
# 11. Reaction Temperature & Reaction Time: 0.2912
# 12. Pore Size & Catalyst_Ni0.5/HAP-OP: 0.2733
# 13. Reaction Temperature & Syngas_Ratio: 0.2705
# 14. Ni Particle Size & Catalyst_15% Ni/CeO2 eMgO: 0.2548
# 15. Ni Loading & Pore Size: 0.2375
# 16. Pore Size & Catalyst_Ni@SiO2-700: 0.2269
# 17. Pore Size & Modifier Electronegativity: 0.2262
# 18. Pore Size & Catalyst_5Ni/La2O3-GNC\: 0.2221
# 19. Reaction Time & GHSV: 0.2195
# 20. Ni Loading & Catalyst_Ni(15)/perlite: 0.2066
# 21. Ratio of CH4 in Feed & Catalyst_NAU: 0.2024
# 22. Ratio of CH4 in Feed & Catalyst_NAW: 0.2024
# 23. Pore Volume & H2-TPR Peak Temperature: 0.2024
# 24. Pore Size & Catalyst_15% Ni/CeO2 eMgO: 0.2014
# 25. H2-TPR Peak Temperature & Ni Particle Size: 0.1990
# 26. Ratio of CH4 in Feed & Catalyst_NAC: 0.1902
# 27. Ni Particle Size & Catalyst_Ni-Zr Srf: 0.1898
# 28. Ni Loading & Pore Volume: 0.1866
# 29. Surface Area & H2-TPR Peak Temperature: 0.1863
# 30. Ratio of CH4 in Feed & Surface Area: 0.1855
# 31. Modifier Electronegativity & Catalyst_Ni−Mn/ Ce50−Zr50: 0.1854
# 32. Pore Size & Ni Particle Size: 0.1851
# 33. Pore Volume & Catalyst_Ni @ Si: 0.1845
# 34. Modifier Electronegativity & Catalyst_2PAl-10Ni: 0.1822
# 35. Pore Volume & Catalyst_Ni@SiO2-1 h: 0.1822
# 36. H2-TPR Peak Temperature & Catalyst_Ni-Ce Srf: 0.1809
# 37. Ratio of CH4 in Feed & Catalyst_Ni−Mn/ Ce50−Zr50: 0.1783
# 38. Ratio of CH4 in Feed & Catalyst_Ni0.5/HAP-OP: 0.1783
# 39. GHSV & Catalyst_Ni/C-Al2O3-700: 0.1773
# 40. GHSV & Catalyst_Ni/M-Al2O3-500: 0.1773
# 41. GHSV & Catalyst_Ni/M-Al2O3-700: 0.1773
# 42. Ratio of CH4 in Feed & CH4 Conversion: 0.1771
# 43. H2-TPR Peak Temperature & Modifier Electronegativity: 0.1769
# 44. Surface Area & Catalyst_9%Y-NiO/ SBA-15: 0.1755
# 45. Modifier Electronegativity & Catalyst_0.2Cu-Ni/SiO2: 0.1752
# 46. Modifier Electronegativity & Catalyst_0.5Cu-Ni/SiO2: 0.1752
# 47. Modifier Electronegativity & Catalyst_1.5Cu-Ni/SiO2: 0.1752
# 48. Reaction Time & Catalyst_2ZrO-Ni/AL2O3: 0.1747
# 49. Reaction Time & Catalyst_5ZrO-Ni/AL2O3: 0.1747
# 50. Reaction Time & Catalyst_10ZrO-Ni/AL2O3: 0.1747
# 51. Modifier Electronegativity & CH4 Conversion: 0.1743
# 52. Pore Volume & Catalyst_Ni/SiO2-E: 0.1743
# 53. Surface Area & Syngas_Ratio: 0.1720
# 54. Pore Size & Catalyst_Ni/15% CeO2− MgO: 0.1707
# 55. Pore Volume & Catalyst_Ni(15)/perlite: 0.1706
# 56. Ni Loading & Catalyst_Ni0.5/HAP-OP: 0.1700
# 57. Reaction Time & Catalyst_Ni/Al2O3: 0.1697
# 58. Ni Loading & Modifier Electronegativity: 0.1689
# 59. Surface Area & Catalyst_Ni/B-SiO2: 0.1687
# 60. Ni Loading & Catalyst_15% Ni/CeO2 eMgO: 0.1678
# 61. Ratio of CH4 in Feed & CO2 Conversion: 0.1673
# 62. Pore Volume & Catalyst_Ni10/SBA-15: 0.1653
# 63. Ratio of CH4 in Feed & Catalyst_Ni/ Ce50− Zr50: 0.1649
# 64. Ratio of CH4 in Feed & GHSV: 0.1643
# 65. H2-TPR Peak Temperature & Catalyst_Ni(15)/perlite: 0.1626
# 66. Modifier Electronegativity & Catalyst_Sn0.02 Ni/Ce-Al: 0.1618
# 67. Pore Volume & Syngas_Ratio: 0.1602
# 68. Pore Size & H2-TPR Peak Temperature: 0.1597
# 69. Pore Volume & Catalyst_TAL100: 0.1591
# 70. Surface Area & Catalyst_NiPS@silica-0.6: 0.1587
# 71. Surface Area & Catalyst_10Ni-SBA-15: 0.1584
# 72. Ni Particle Size & Catalyst_Ni-Ce Srf: 0.1575
# 73. Ni Particle Size & Catalyst_Ni-LaCe 1:1: 0.1568
# 74. Ni Particle Size & Catalyst_Ni0.5/HAP-OP: 0.1567
# 75. Ratio of CH4 in Feed & H2-TPR Peak Temperature: 0.1562
# 76. Pore Size & Catalyst_Ni @ Si: 0.1559
# 77. Ni Particle Size & Catalyst_Ni(15)/perlite: 0.1557
# 78. Syngas_Ratio & Catalyst_Ni/Ce: 0.1549
# 79. Ratio of CH4 in Feed & Catalyst_Ni(15)/perlite: 0.1547
# 80. Pore Size & Catalyst_10AC-Ni/MgO-Al2O3: 0.1537
# 81. Pore Size & Catalyst_Ni/MgO-Al2O3: 0.1537
# 82. Pore Volume & Catalyst_Ni@HSZ-reduced: 0.1534
# 83. GHSV & Catalyst_Ni/Ce: 0.1518
# 84. Ni Particle Size & Catalyst_Ni@SiO2-500: 0.1514
# 85. Surface Area & Catalyst_Ni(15)/perlite: 0.1504
# 86. CO2 Conversion & Catalyst_Ni-SiO2- NaOH: 0.1503
# 87. Ni Loading & Catalyst_15%Ni-MgO-Al2O3: 0.1500
# 88. H2-TPR Peak Temperature & Catalyst_Ni−Mn/ Ce50−Zr50: 0.1490
# 89. Syngas_Ratio & Catalyst_Ni/SiO2-E: 0.1488
# 90. Surface Area & Catalyst_5Ni9Ce-SBA-15: 0.1487
# 91. Surface Area & Modifier Electronegativity: 0.1486
# 92. Modifier Electronegativity & Catalyst_0.5PAl-10Ni: 0.1486
# 93. Modifier Electronegativity & Catalyst_1PAl-10Ni: 0.1486
# 94. Modifier Electronegativity & Catalyst_4PAl-10Ni: 0.1486
# 95. Modifier Electronegativity & Catalyst_6PAl-10Ni: 0.1486
# 96. Pore Size & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.1481
# 97. Reaction Temperature & Catalyst_NiZr: 0.1479
# 98. Reaction Temperature & Catalyst_NiCe: 0.1479
# 99. Reaction Temperature & Catalyst_Ni/SiO2-E: 0.1479
# 100. Ni Loading & Catalyst_Ni @ Si: 0.1460
# 101. Ni Loading & Ni Particle Size: 0.1447
# 102. Modifier Electronegativity & Catalyst_10Ni-3Fe-MgAl2O4: 0.1444
# 103. Pore Volume & Catalyst_0.2Cu-Ni/SiO2: 0.1430
# 104. Surface Area & Catalyst_6%Y-NiO/SBA-15: 0.1429
# 105. Ni Particle Size & Catalyst_Ni@SiO2-600: 0.1428
# 106. Pore Size & Catalyst_Ni@SiO2-600: 0.1424
# 107. Ni Loading & Catalyst_HNiZr3: 0.1414
# 108. Surface Area & Catalyst_Ni-SiO2- NH3·- H2O: 0.1411
# 109. Ni Particle Size & Catalyst_10%Ni/CeO2: 0.1407
# 110. Ni Particle Size & Catalyst_Ni/B-SiO2: 0.1400
# 111. Ni Loading & Catalyst_NAW: 0.1397
# 112. Pore Size & Catalyst_Ni(15)/perlite: 0.1390
# 113. H2-TPR Peak Temperature & Catalyst_Ni10CeAl: 0.1390
# 114. Ratio of CH4 in Feed & Catalyst_Ni/CeZr: 0.1383
# 115. Syngas_Ratio & Catalyst_NiPS@silica-0.6: 0.1383
# 116. Ratio of CH4 in Feed & Ni Loading: 0.1382
# 117. Pore Volume & Catalyst_Ni/Al2O3 -Nit: 0.1379
# 118. Ni Particle Size & Catalyst_Sn0.02 Ni/Ce-Al: 0.1375
# 119. Reaction Temperature & Catalyst_CB‐LDO: 0.1366
# 120. Reaction Time & Syngas_Ratio: 0.1362
# 121. Pore Volume & Catalyst_1.5Cu-Ni/SiO2: 0.1356
# 122. CO2 Conversion & Catalyst_Ni/SiO2-E: 0.1351
# 123. CH4 Conversion & Catalyst_Ni0.5/HAP-OP: 0.1345
# 124. Ratio of CH4 in Feed & Catalyst_NAF: 0.1344
# 125. GHSV & Catalyst_Ce-NHS-SiO2-S: 0.1340
# 126. Surface Area & Catalyst_Ni10/SBA-15: 0.1334
# 127. Modifier Electronegativity & GHSV: 0.1328
# 128. Pore Size & Catalyst_Ni/SiO2-E: 0.1323
# 129. Pore Size & Catalyst_Ni-Ce Srf: 0.1321
# 130. Ni Loading & Catalyst_NAC: 0.1314
# 131. Reaction Time & Pore Volume: 0.1309
# 132. Surface Area & Catalyst_NiPS@silica-0.4: 0.1305
# 133. Syngas_Ratio & Catalyst_Ni/CS-DP: 0.1302
# 134. Ni Loading & Catalyst_NAU: 0.1298
# 135. Surface Area & Catalyst_3%Y-NiO/SBA-15: 0.1296
# 136. Ni Particle Size & Catalyst_Ni@SiO2-700: 0.1290
# 137. H2-TPR Peak Temperature & Catalyst_Ni@SiO2-500: 0.1288
# 138. H2-TPR Peak Temperature & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.1286
# 139. H2-TPR Peak Temperature & Catalyst_Ni/15% CeO2− MgO: 0.1283
# 140. Ni Loading & Catalyst_NiAl/La perovskite: 0.1275
# 141. Pore Volume & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.1263
# 142. GHSV & Catalyst_NiAl/La perovskite: 0.1263
# 143. GHSV & Catalyst_CeO2@Ni/SiO2: 0.1263
# 144. GHSV & Catalyst_Ni-CeO2/SiO2: 0.1263
# 145. Reaction Temperature & GHSV: 0.1261
# 146. H2-TPR Peak Temperature & Catalyst_1.5Cu-Ni/SiO2: 0.1261
# 147. Surface Area & Catalyst_Ni−SiO2‑750: 0.1260
# 148. Surface Area & Catalyst_Ni−SiO2‑550: 0.1260
# 149. Pore Size & Catalyst_Ni@SiO2-500: 0.1258
# 150. H2-TPR Peak Temperature & Catalyst_Ni/CeZr: 0.1257
# 151. GHSV & Catalyst_Ni12MgAl: 0.1253
# 152. GHSV & Catalyst_0.5 K-Ni/MgAl2O4: 0.1253
# 153. GHSV & Catalyst_0.7 K-Ni/ MgAl2O4: 0.1253
# 154. GHSV & Catalyst_0.2 K-Ni/ MgAl2O4: 0.1253
# 155. GHSV & Catalyst_0.4 K-Ni/ MgAl2O4: 0.1253
# 156. GHSV & Catalyst_Ni/MgAl2O4: 0.1253
# 157. Surface Area & Catalyst_10Ni9Ce-SBA-15: 0.1249
# 158. CO2 Conversion & Catalyst_Ni0.5/HAP-OP: 0.1247
# 159. Pore Volume & Catalyst_Ni@SiO2-2 h: 0.1246
# 160. Syngas_Ratio & Catalyst_NAU: 0.1235
# 161. Pore Size & Catalyst_Ni10CeAl: 0.1235
# 162. Ni Loading & Catalyst_2.5%Ni-MgO-Al2O3: 0.1234
# 163. Ni Particle Size & Catalyst_Ni/15% CeO2− MgO: 0.1229
# 164. CO2 Conversion & Catalyst_6PAl-10Ni: 0.1226
# 165. H2-TPR Peak Temperature & Catalyst_12.5%Ni-MgO-Al2O3: 0.1222
# 166. H2-TPR Peak Temperature & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.1215
# 167. CH4 Conversion & Catalyst_10Ni-3La-MgAl2O4: 0.1213
# 168. Ratio of CH4 in Feed & Pore Volume: 0.1207
# 169. CH4 Conversion & Catalyst_10Ni-3Zr-MgAl2O4: 0.1203
# 170. Pore Volume & Catalyst_Ni@SiO2-500: 0.1203
# 171. Pore Volume & Catalyst_Ni−Mn/ Ce50−Zr50: 0.1202
# 172. Syngas_Ratio & Catalyst_1.5Cu-Ni/SiO2: 0.1201
# 173. H2-TPR Peak Temperature & Catalyst_4PAl-10Ni: 0.1200
# 174. CH4 Conversion & Catalyst_Ni/SiO2-E: 0.1200
# 175. Ni Particle Size & Catalyst_5Ni/La2O3-PP: 0.1197
# 176. H2-TPR Peak Temperature & Catalyst_Ni-Zr Srf: 0.1192
# 177. Ni Particle Size & Catalyst_Ni1.5/HAP-OP: 0.1185
# 178. Surface Area & Catalyst_Ni/Sn0.2−SiO2‑550: 0.1180
# 179. Surface Area & Catalyst_Ni/Sn0.2−SiO2‑750: 0.1180
# 180. Pore Volume & Catalyst_5Ni/La2O3-GNC\: 0.1180
# 181. Ni Particle Size & Catalyst_Ni/SC: 0.1178
# 182. Surface Area & Catalyst_Ni/0La–Si: 0.1174
# 183. CH4 Conversion & Catalyst_10Ni-3Ca-MgAl2O4: 0.1174
# 184. Pore Volume & Catalyst_Ni-Al Pol: 0.1174
# 185. Ni Loading & Catalyst_12.5%Ni-MgO-Al2O3: 0.1169
# 186. Ni Loading & Catalyst_Ni/SBA15: 0.1169
# 187. Ratio of CH4 in Feed & Catalyst_TAL100: 0.1163
# 188. Ratio of CH4 in Feed & Catalyst_TAL0: 0.1163
# 189. Ratio of CH4 in Feed & Catalyst_TAL25: 0.1163
# 190. Ratio of CH4 in Feed & Catalyst_TAL50: 0.1163
# 191. Ratio of CH4 in Feed & Catalyst_TAL75: 0.1163
# 192. Ratio of CH4 in Feed & Catalyst_Ni–ZrOx: 0.1163
# 193. Ni Particle Size & Catalyst_NAU: 0.1161
# 194. Syngas_Ratio & Catalyst_NiZr: 0.1159
# 195. H2-TPR Peak Temperature & Catalyst_Ni@SiO2-600: 0.1152
# 196. H2-TPR Peak Temperature & Catalyst_Ni@SiO2-700: 0.1152
# 197. Surface Area & Catalyst_Ni@SiO2-500: 0.1151
# 198. Pore Volume & Catalyst_TAL75: 0.1141
# 199. Pore Volume & Catalyst_5Ni/La2O3-PP: 0.1139
# 200. CH4 Conversion & Catalyst_NAW: 0.1138
# 201. Pore Size & Catalyst_5Ni/La2O3-PP: 0.1133
# 202. H2-TPR Peak Temperature & Catalyst_10Ni/Al2O3: 0.1129
# 203. Ratio of CH4 in Feed & Catalyst_NiZr: 0.1128
# 204. Ratio of CH4 in Feed & Catalyst_NiCe: 0.1128
# 205. Ni Particle Size & Catalyst_Ni-Al Srf: 0.1126
# 206. Ni Particle Size & Catalyst_Ni1/HAP-OP: 0.1122
# 207. Ni Particle Size & Catalyst_10%Ni/Ce0.95Mn0.05: 0.1120
# 208. Syngas_Ratio & Catalyst_Ni/ Ce50− Zr50: 0.1118
# 209. Pore Volume & Catalyst_Ni/CS-DP: 0.1115
# 210. Syngas_Ratio & Catalyst_TAL50: 0.1114
# 211. Pore Volume & Catalyst_Ni/ Ce50− Zr50: 0.1112
# 212. Surface Area & Catalyst_10Ni-3Zr-MgAl2O4: 0.1107
# 213. CH4 Conversion & Catalyst_NAU: 0.1106
# 214. Surface Area & Catalyst_10%Ni/Ce0.95Mn0.05: 0.1103
# 215. Ratio of CH4 in Feed & Reaction Time: 0.1099
# 216. Syngas_Ratio & Catalyst_Ni-SiO2- NaOH: 0.1098
# 217. Syngas_Ratio & Catalyst_TAL25: 0.1098
# 218. Syngas_Ratio & Catalyst_10Ni-3Zr-MgAl2O4: 0.1098
# 219. Syngas_Ratio & Catalyst_10ZrO-Ni/AL2O3: 0.1096
# 220. H2-TPR Peak Temperature & Catalyst_10%Ni/Ce0.95Mn0.05: 0.1095
# 221. Modifier Electronegativity & CO2 Conversion: 0.1089
# 222. Ni Loading & Catalyst_Ni@SiO2: 0.1087
# 223. Syngas_Ratio & Catalyst_NAC: 0.1081
# 224. Syngas_Ratio & Catalyst_TAL0: 0.1081
# 225. Ni Particle Size & Catalyst_Ni/1ZnAl: 0.1080
# 226. H2-TPR Peak Temperature & Catalyst_NAU: 0.1078
# 227. Syngas_Ratio & Catalyst_Ni@HSZ-reduced: 0.1078
# 228. GHSV & Catalyst_Ni/(-Al2O3): 0.1072
# 229. GHSV & Catalyst_Ni/(Al2O3-Crush): 0.1072
# 230. GHSV & Catalyst_Ni/(Al2O3-Sigma): 0.1072
# 231. Ni Particle Size & Catalyst_Ni-Ce Pol: 0.1071
# 232. H2-TPR Peak Temperature & Catalyst_5%Ni-MgO-Al2O3: 0.1070
# 233. Surface Area & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.1067
# 234. Surface Area & Catalyst_5Ni/La2O3-PP: 0.1067
# 235. Syngas_Ratio & Catalyst_Ni-Zr Pol: 0.1064
# 236. CO2 Conversion & Catalyst_NiPS@silica-0.6: 0.1062
# 237. CO2 Conversion & Catalyst_Ni/Sn0.2−SiO2‑750: 0.1059
# 238. Ni Loading & Catalyst_Ni/3.0La–Si-imp: 0.1059
# 239. Ni Loading & Catalyst_Ni/0La–Si: 0.1059
# 240. Ni Loading & Catalyst_Ni/1La–Si: 0.1059
# 241. Ni Loading & Catalyst_Ni/2La–Si: 0.1059
# 242. Ni Loading & Catalyst_Ni/3La–Si: 0.1059
# 243. Ni Loading & Catalyst_Ni/5La–Si: 0.1059
# 244. Ni Loading & Catalyst_Ni/7La–Si: 0.1059
# 245. Ni Loading & Catalyst_Ni–3.0La/Si-imp: 0.1059
# 246. Ni Loading & Catalyst_15Ni/DFSBA-15: 0.1059
# 247. Surface Area & Catalyst_5Ni/La2O3-GNC\: 0.1058
# 248. Reaction Time & CO2 Conversion: 0.1054
# 249. CH4 Conversion & Catalyst_10Ni/g-Al2O3: 0.1053
# 250. Ratio of CH4 in Feed & Pore Size: 0.1048
# 251. Modifier Electronegativity & Catalyst_5%Ni–3%MgO/Al2O: 0.1045
# 252. Surface Area & Catalyst_Ni/SN: 0.1039
# 253. Syngas_Ratio & Catalyst_10Ni-MgAl2O4: 0.1038
# 254. CH4 Conversion & Catalyst_NAC: 0.1037
# 255. Pore Volume & Catalyst_Ni@SiO2-10 h: 0.1036
# 256. Ni Loading & Catalyst_CeO2@Ni-Ps CS: 0.1032
# 257. Ratio of CH4 in Feed & Catalyst_Ni10CeAl: 0.1030
# 258. H2-TPR Peak Temperature & Catalyst_2PAl-10Ni: 0.1029
# 259. Reaction Temperature & Ni Loading: 0.1029
# 260. CH4 Conversion & Catalyst_NiPS@silica-0.6: 0.1028
# 261. Ni Loading & Catalyst_Ce (20)-Ni(15)/perlite: 0.1028
# 262. Ni Loading & Catalyst_Zr (20)-Ni(15)/perlite,: 0.1028
# 263. Ni Loading & Catalyst_Zr (10)-Ni(15)/ perlite: 0.1028
# 264. Pore Size & Catalyst_Ni0.5/HAP: 0.1028
# 265. Pore Size & Catalyst_Ni1.5/HAP-OP: 0.1028
# 266. Pore Size & Catalyst_Ni1/HAP-OP: 0.1028
# 267. Pore Size & Catalyst_5Ni/La2O3-C: 0.1027
# 268. CH4 Conversion & Catalyst_10Ni-3Fe-MgAl2O4: 0.1021
# 269. CO2 Conversion & Catalyst_Ni/MgO: 0.1016
# 270. Ni Loading & Reaction Time: 0.1016
# 271. Surface Area & Catalyst_1%B-Ni/SBA-15: 0.1014
# 272. Syngas_Ratio & Catalyst_2ZrO-Ni/AL2O3: 0.1013
# 273. Pore Size & Catalyst_10%Ni/Ce0.75Mn0.25: 0.1013
# 274. Ni Loading & Catalyst_Ce (10)-Ni(15)/perlite,: 0.1013
# 275. CH4 Conversion & Catalyst_10Ni-MgAl2O4: 0.1012
# 276. Reaction Time & Catalyst_Mg–Ni–La2O3: 0.1007
# 277. Reaction Time & Catalyst_–Ni–La2O3: 0.1007
# 278. Reaction Time & Catalyst_5Ni/La2O3-C: 0.1007
# 279. Reaction Time & Catalyst_K–Ni–La2O3: 0.1007
# 280. Reaction Time & Catalyst_Li–Ni–La2O3: 0.1007
# 281. Reaction Time & Catalyst_Cs–Ni–La2O3: 0.1007
# 282. Reaction Time & Catalyst_Ni–La2O3: 0.1007
# 283. Reaction Time & Catalyst_Ni/AL2O3: 0.1007
# 284. Reaction Time & Catalyst_CeO2@Ni-Ps CS: 0.1007
# 285. Syngas_Ratio & Catalyst_Ni/SiO2: 0.1006
# 286. CO2 Conversion & Catalyst_NAU: 0.1004
# 287. Pore Size & Catalyst_Ni/LaAlO3: 0.1002
# 288. H2-TPR Peak Temperature & Catalyst_Ce(0)-NMA-COP: 0.1001
# 289. GHSV & Catalyst_Ni(15)/perlite: 0.1001
# 290. Ni Particle Size & GHSV: 0.0999
# 291. Reaction Time & Catalyst_Ni/SBA15: 0.0999
# 292. Modifier Electronegativity & Catalyst_NiO−10Al2O3−ZrO2: 0.0995
# 293. Syngas_Ratio & Catalyst_10Ni/g-Al2O3: 0.0993
# 294. GHSV & Catalyst_Ni-Al Srf: 0.0992
# 295. GHSV & Catalyst_Ni-Ce Srf: 0.0992
# 296. GHSV & Catalyst_Ni-Zr Srf: 0.0992
# 297. Modifier Electronegativity & Catalyst_NiAl/La perovskite: 0.0987
# 298. H2-TPR Peak Temperature & Catalyst_1PAl-10Ni: 0.0986
# 299. Surface Area & Catalyst_10Ni-3Fe-MgAl2O4: 0.0983
# 300. CH4 Conversion & Catalyst_Ni/MgO: 0.0982
# 301. Syngas_Ratio & Catalyst_TAL75: 0.0981
# 302. Syngas_Ratio & Catalyst_Ce-NHS-SiO2-S: 0.0980
# 303. Syngas_Ratio & Catalyst_Ni-LaCe 1:4: 0.0976
# 304. Reaction Temperature & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0975
# 305. Pore Volume & Catalyst_Ni/SiO2: 0.0973
# 306. Ni Loading & Catalyst_NAF: 0.0971
# 307. Ni Particle Size & Catalyst_Ni/TiSiO2gr: 0.0968
# 308. Reaction Time & Catalyst_NAC: 0.0967
# 309. CH4 Conversion & Catalyst_Ni/Ce: 0.0967
# 310. Ni Loading & Catalyst_NiY3-DLH: 0.0967
# 311. Surface Area & Catalyst_10Ni-3Ce-MgAl2O4: 0.0966
# 312. Syngas_Ratio & Catalyst_10Ni-3Ca-MgAl2O4: 0.0965
# 313. Syngas_Ratio & Catalyst_10Ni-3Fe-MgAl2O4: 0.0965
# 314. Ni Loading & Catalyst_Ni@SiO2@ZrO2-reduced: 0.0964
# 315. CO2 Conversion & Catalyst_Ni/Ce: 0.0963
# 316. Reaction Time & Catalyst_Ni10CeAl: 0.0962
# 317. Reaction Time & Catalyst_NAW: 0.0962
# 318. Reaction Time & Catalyst_NAU: 0.0962
# 319. Modifier Electronegativity & Syngas_Ratio: 0.0959
# 320. Pore Volume & Catalyst_Ni/CS-BM: 0.0957
# 321. CH4 Conversion & Catalyst_TAL75: 0.0956
# 322. Pore Volume & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0956
# 323. CH4 Conversion & Catalyst_10Ni-3Ce-MgAl2O4: 0.0956
# 324. Surface Area & Catalyst_Ni/SH: 0.0955
# 325. CH4 Conversion & Catalyst_Ni-SiO2- NaOH: 0.0955
# 326. Pore Volume & Catalyst_Ni/3CS: 0.0954
# 327. Ni Loading & Catalyst_Ce(0)-NMA-COP: 0.0953
# 328. Ni Loading & Catalyst_Ce(1)-NMA-COP: 0.0953
# 329. Ni Loading & Catalyst_Ce(3)-NMA-COP: 0.0953
# 330. Ni Loading & Catalyst_Ce(5)-NMA-COP: 0.0953
# 331. Ni Loading & Catalyst_Ce(1)-NMA-IMP: 0.0953
# 332. Ni Loading & Catalyst_Ce(3)-NMA-IMP: 0.0953
# 333. Ni Loading & Catalyst_Ce(5)-NMA-IMP: 0.0953
# 334. Reaction Time & Catalyst_Ni/La-SC: 0.0951
# 335. Reaction Time & Catalyst_Ni/La-ST: 0.0951
# 336. Reaction Time & Catalyst_Ni@SiO2-10 h: 0.0951
# 337. Reaction Time & Catalyst_Ni@SiO2-5 h: 0.0951
# 338. Reaction Time & Catalyst_Ni/La-HP: 0.0951
# 339. Reaction Time & Catalyst_Ni/La-ME: 0.0951
# 340. Reaction Time & Catalyst_Ni@SiO2-1 h: 0.0951
# 341. Reaction Time & Catalyst_Ni@SiO2-2 h: 0.0951
# 342. Reaction Time & Catalyst_Ni/La-SG: 0.0951
# 343. Reaction Time & Catalyst_Ni-4: 0.0951
# 344. Reaction Time & Catalyst_Ni-6: 0.0951
# 345. Reaction Time & Catalyst_Ni-8: 0.0951
# 346. Reaction Time & Catalyst_Ni/MM-A: 0.0951
# 347. Reaction Time & Catalyst_Ni-2: 0.0951
# 348. Reaction Time & Catalyst_Ni-IMP: 0.0951
# 349. Reaction Time & Catalyst_Ni/MA: 0.0951
# 350. Reaction Time & Catalyst_Ni@HSZ-reduced: 0.0951
# 351. Reaction Time & Catalyst_Ni@SiO2@ZrO2-reduced: 0.0951
# 352. Ni Particle Size & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.0951
# 353. Ratio of CH4 in Feed & Catalyst_HNiZr3: 0.0949
# 354. Ratio of CH4 in Feed & Catalyst_NiO−10Al2O3−ZrO2: 0.0949
# 355. Ratio of CH4 in Feed & Catalyst_NiO−ZrO2: 0.0949
# 356. Ratio of CH4 in Feed & Catalyst_Ni5%Al2O3: 0.0949
# 357. CH4 Conversion & Catalyst_TAL50: 0.0949
# 358. Surface Area & Catalyst_10Ni-3La-MgAl2O4: 0.0949
# 359. Reaction Temperature & Catalyst_10Ni-MgAl2O4: 0.0948
# 360. Pore Volume & Catalyst_3%Y-NiO/SBA-15: 0.0948
# 361. Pore Volume & Catalyst_9%Y-NiO/ SBA-15: 0.0948
# 362. CO2 Conversion & Catalyst_NAW: 0.0948
# 363. Surface Area & Catalyst_Ni/1La–Si: 0.0947
# 364. Reaction Temperature & Catalyst_10Ni-3Fe-MgAl2O4: 0.0946
# 365. Reaction Temperature & Catalyst_10Ni-3La-MgAl2O4: 0.0946
# 366. Reaction Temperature & Catalyst_10Ni-3Zr-MgAl2O4: 0.0946
# 367. Reaction Temperature & Catalyst_10Ni-3Ca-MgAl2O4: 0.0946
# 368. Reaction Temperature & Catalyst_10Ni-3Ce-MgAl2O4: 0.0946
# 369. Reaction Time & Catalyst_3%Y-NiO/SBA-15: 0.0945
# 370. Reaction Time & Catalyst_6%Y-NiO/SBA-15: 0.0945
# 371. Reaction Time & Catalyst_9%Y-NiO/ SBA-15: 0.0945
# 372. Pore Volume & Catalyst_Ni-Zr Pol: 0.0945
# 373. Pore Volume & Catalyst_Ni-Ce Pol: 0.0945
# 374. Surface Area & Catalyst_15% Ni/CeO2 eMgO: 0.0944
# 375. H2-TPR Peak Temperature & Catalyst_0.5PAl-10Ni: 0.0944
# 376. Pore Size & Catalyst_Ni0.15Mg0.85O: 0.0944
# 377. H2-TPR Peak Temperature & Catalyst_Ni/Ce: 0.0943
# 378. Surface Area & Catalyst_Ni/2La–Si: 0.0942
# 379. H2-TPR Peak Temperature & Catalyst_15%Ni-MgO-Al2O3: 0.0941
# 380. H2-TPR Peak Temperature & Catalyst_10%Ni-MgO-Al2O3: 0.0941
# 381. Pore Size & Catalyst_Ni/La-ME: 0.0941
# 382. H2-TPR Peak Temperature & Catalyst_NiCe: 0.0939
# 383. H2-TPR Peak Temperature & Catalyst_10Ni9Ce-SBA-15: 0.0939
# 384. H2-TPR Peak Temperature & Catalyst_10Ni18Ce-SBA-15: 0.0939
# 385. Ni Particle Size & Catalyst_Ni/SBA15: 0.0939
# 386. GHSV & Catalyst_Ni/Al2O3: 0.0939
# 387. Surface Area & Catalyst_Ni/3La–Si: 0.0936
# 388. Pore Size & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0935
# 389. Syngas_Ratio & Catalyst_Ni-LaCe 1:1: 0.0935
# 390. Modifier Electronegativity & Catalyst_10Ni-3Zr-MgAl2O4: 0.0935
# 391. Modifier Electronegativity & Catalyst_10ZrO-Ni/AL2O3: 0.0935
# 392. Modifier Electronegativity & Catalyst_2ZrO-Ni/AL2O3: 0.0935
# 393. Modifier Electronegativity & Catalyst_5ZrO-Ni/AL2O3: 0.0935
# 394. Ni Particle Size & Catalyst_Ce-NHS-SiO2-S: 0.0935
# 395. Ni Particle Size & Catalyst_NHS-SiO2-S: 0.0935
# 396. Pore Volume & Catalyst_Ni/CeZr: 0.0934
# 397. CH4 Conversion & Catalyst_TAL100: 0.0934
# 398. Pore Size & Catalyst_Ni–ZrOx: 0.0933
# 399. Modifier Electronegativity & Catalyst_1%B-Ni/SBA-15: 0.0933
# 400. Modifier Electronegativity & Catalyst_2%B-Ni/SBA-15: 0.0933
# 401. Modifier Electronegativity & Catalyst_3%B-Ni/SBA-15: 0.0933
# 402. Modifier Electronegativity & Catalyst_5%B-Ni/SBA-15: 0.0933
# 403. Modifier Electronegativity & Catalyst_Sn0.02 Ni/Al: 0.0933
# 404. Modifier Electronegativity & Catalyst_Sn0.04 Ni/Al: 0.0933
# 405. Modifier Electronegativity & Catalyst_NiB(0.1)/Al: 0.0933
# 406. Modifier Electronegativity & Catalyst_NiB(0.3)/Al: 0.0933
# 407. Modifier Electronegativity & Catalyst_NiB(0.5)/Al: 0.0933
# 408. Modifier Electronegativity & Catalyst_NiB(0.7)/Al: 0.0933
# 409. CO2 Conversion & Catalyst_Ni/Sn0.2−SiO2‑550: 0.0932
# 410. Ni Loading & Catalyst_Ni/Ce: 0.0931
# 411. Syngas_Ratio & Catalyst_TAL100: 0.0931
# 412. CO2 Conversion & Catalyst_2.5%Ni-MgO-Al2O3: 0.0931
# 413. H2-TPR Peak Temperature & Catalyst_Ce (20)-Ni(15)/perlite: 0.0930
# 414. H2-TPR Peak Temperature & Catalyst_Ni-CeO2/SiO2: 0.0930
# 415. H2-TPR Peak Temperature & Catalyst_7.5%Ni-MgO-Al2O3: 0.0928
# 416. Modifier Electronegativity & Catalyst_3%Y-NiO/SBA-15: 0.0927
# 417. Modifier Electronegativity & Catalyst_6%Y-NiO/SBA-15: 0.0927
# 418. Modifier Electronegativity & Catalyst_9%Y-NiO/ SBA-15: 0.0927
# 419. CH4 Conversion & Catalyst_TAL25: 0.0927
# 420. GHSV & Catalyst_NiCe: 0.0923
# 421. GHSV & Catalyst_NiZr: 0.0923
# 422. GHSV & Catalyst_2ZrO-Ni/AL2O3: 0.0923
# 423. GHSV & Catalyst_5ZrO-Ni/AL2O3: 0.0923
# 424. GHSV & Catalyst_10ZrO-Ni/AL2O3: 0.0923
# 425. H2-TPR Peak Temperature & Catalyst_Ce(5)-NMA-IMP: 0.0923
# 426. CO2 Conversion & Catalyst_Ni/Al2O3 -Ole: 0.0923
# 427. Reaction Temperature & Catalyst_Ni0.5/HAP-OP: 0.0923
# 428. Syngas_Ratio & Catalyst_10Ni/TS (50:50): 0.0923
# 429. Surface Area & Catalyst_Ni−Mn/ Ce50−Zr50: 0.0919
# 430. Pore Volume & Catalyst_TAL25: 0.0917
# 431. Ni Loading & Catalyst_0.2Cu-Ni/SiO2: 0.0917
# 432. Ni Loading & Catalyst_0.5Cu-Ni/SiO2: 0.0917
# 433. CO2 Conversion & Catalyst_NAC: 0.0916
# 434. Syngas_Ratio & Catalyst_Ni@SiO2@ZrO2-reduced: 0.0915
# 435. Syngas_Ratio & Catalyst_Ni-Ce Pol: 0.0915
# 436. H2-TPR Peak Temperature & Catalyst_Ce (10)-Ni(15)/perlite,: 0.0913
# 437. Ni Loading & Syngas_Ratio: 0.0913
# 438. Surface Area & Catalyst_10Ni-3Ca-MgAl2O4: 0.0913
# 439. Ni Loading & Catalyst_1.5Cu-Ni/SiO2: 0.0912
# 440. GHSV & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0911
# 441. Reaction Temperature & Pore Size: 0.0911
# 442. Surface Area & Catalyst_10Ni18Ce-SBA-15: 0.0909
# 443. Modifier Electronegativity & Catalyst_Ni/Sn0.2−SiO2‑550: 0.0909
# 444. Modifier Electronegativity & Catalyst_Ni/Sn0.2−SiO2‑750: 0.0909
# 445. Modifier Electronegativity & Catalyst_Ni−SiO2‑550: 0.0909
# 446. Modifier Electronegativity & Catalyst_Ni−SiO2‑750: 0.0909
# 447. Ratio of CH4 in Feed & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0907
# 448. Ni Loading & Catalyst_Ni@HSZ-reduced: 0.0902
# 449. Surface Area & Catalyst_Ni/5La–Si: 0.0898
# 450. Syngas_Ratio & Catalyst_10Ni-3Ce-MgAl2O4: 0.0898
# 451. Surface Area & Catalyst_Ni0.5/HAP-OP: 0.0898
# 452. Ni Particle Size & Catalyst_Ni/FA-M3: 0.0898
# 453. Ni Particle Size & Catalyst_Ni/TiSiO2sg: 0.0898
# 454. Ni Particle Size & Catalyst_Ni−Mn/ Ce50−Zr50: 0.0896
# 455. CO2 Conversion & Catalyst_Ni/Al2O3 -Nit: 0.0896
# 456. CH4 Conversion & Catalyst_Ni/SBA15: 0.0896
# 457. Reaction Time & Catalyst_NiAl/La perovskite: 0.0895
# 458. GHSV & Catalyst_Ni/MAD: 0.0892
# 459. GHSV & Catalyst_Ni/MAD+PegMn: 0.0892
# 460. GHSV & Catalyst_Ni/LaAlO3: 0.0892
# 461. Surface Area & Catalyst_10%Ni/CeO2: 0.0891
# 462. Ni Particle Size & Catalyst_Ni/5% CeO2− MgO: 0.0891
# 463. Ni Loading & Catalyst_HNiZr10: 0.0890
# 464. Pore Size & Catalyst_15AC-Ni/MgO-Al2O3: 0.0886
# 465. Pore Size & Catalyst_20AC-Ni/MgO-Al2O3: 0.0886
# 466. Pore Size & Catalyst_50AC-Ni/MgO-Al2O3: 0.0886
# 467. Pore Size & Catalyst_5AC-Ni/MgO-Al2O3: 0.0886
# 468. Pore Size & Catalyst_Ni/10% CeO2− MgO: 0.0886
# 469. CO2 Conversion & Catalyst_Ni/ Ce50− Zr50: 0.0885
# 470. H2-TPR Peak Temperature & Catalyst_Ni-LaCe 1:1: 0.0884
# 471. Pore Volume & Modifier Electronegativity: 0.0884
# 472. Pore Size & Catalyst_Ni@SiO2: 0.0883
# 473. H2-TPR Peak Temperature & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0881
# 474. H2-TPR Peak Temperature & Catalyst_CeO2@Ni/SiO2: 0.0874
# 475. Pore Volume & Catalyst_Ni-Al Srf: 0.0874
# 476. Modifier Electronegativity & Catalyst_NiCu/EXVTM-SiO2: 0.0874
# 477. Ni Particle Size & Catalyst_11NiO/MgO-PWAC: 0.0874
# 478. Syngas_Ratio & Catalyst_10Ni/Al: 0.0873
# 479. Reaction Time & Catalyst_Ni/Si-MCeZr−0.40c: 0.0873
# 480. Reaction Time & Catalyst_Ni/Si-MCeZr−0.05c: 0.0873
# 481. Reaction Time & Catalyst_Ni/Si-MCeZr−0.15c: 0.0873
# 482. Reaction Time & Catalyst_Ni/Si-MCeZr−0.25c: 0.0873
# 483. Reaction Time & Catalyst_Ni/MCeZrc: 0.0873
# 484. Syngas_Ratio & Catalyst_10Ni-3La-MgAl2O4: 0.0871
# 485. GHSV & Catalyst_Sn0.02 Ni/Ce-Al: 0.0871
# 486. Syngas_Ratio & Catalyst_Ni@SiO2-700: 0.0871
# 487. H2-TPR Peak Temperature & Catalyst_NAW: 0.0870
# 488. Pore Volume & Catalyst_10%Ni/CeO2: 0.0869
# 489. Syngas_Ratio & Catalyst_NAW: 0.0869
# 490. H2-TPR Peak Temperature & Catalyst_Ni/SiO2-E: 0.0868
# 491. H2-TPR Peak Temperature & Catalyst_Ce(1)-NMA-IMP: 0.0868
# 492. H2-TPR Peak Temperature & Catalyst_Ce(3)-NMA-IMP: 0.0868
# 493. GHSV & Catalyst_Ni@SiO2-500: 0.0865
# 494. GHSV & Catalyst_Ni@SiO2-600: 0.0865
# 495. GHSV & Catalyst_Ni@SiO2-700: 0.0865
# 496. Ni Particle Size & Catalyst_Ni-Zr Pol: 0.0865
# 497. Modifier Electronegativity & Catalyst_NiCo/EXVTM-SiO2: 0.0862
# 498. Modifier Electronegativity & Catalyst_NiCo/mesoporousAl: 0.0862
# 499. Modifier Electronegativity & Catalyst_Ni12MgAl: 0.0862
# 500. Syngas_Ratio & Catalyst_NHS-SCS0.6-S: 0.0862
# 501. CH4 Conversion & Catalyst_Ni/Sn0.2−SiO2‑750: 0.0860
# 502. CH4 Conversion & Catalyst_TAL0: 0.0859
# 503. CH4 Conversion & Catalyst_2.5%Ni-MgO-Al2O3: 0.0859
# 504. GHSV & Catalyst_Ni-Al Pol: 0.0858
# 505. GHSV & Catalyst_Ni-Ce Pol: 0.0858
# 506. GHSV & Catalyst_Ni-Zr Pol: 0.0858
# 507. Reaction Time & CH4 Conversion: 0.0858
# 508. Ni Loading & Catalyst_NiY4-DLH: 0.0857
# 509. Ni Loading & Catalyst_Ni@SiO2-10 h: 0.0856
# 510. Ratio of CH4 in Feed & Syngas_Ratio: 0.0855
# 511. Ni Loading & Surface Area: 0.0852
# 512. H2-TPR Peak Temperature & Catalyst_Ni-Al Srf: 0.0849
# 513. Syngas_Ratio & Catalyst_Ni-Al Pol: 0.0848
# 514. Surface Area & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0848
# 515. Reaction Time & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0847
# 516. Reaction Time & Catalyst_Ni−Mn/ Ce50−Zr50: 0.0847
# 517. CH4 Conversion & Catalyst_Ni/Al2O3 -Ole: 0.0845
# 518. CH4 Conversion & Catalyst_Sn0.02 Ni/Ce-Al: 0.0844
# 519. CO2 Conversion & Catalyst_TAL25: 0.0844
# 520. Syngas_Ratio & Catalyst_Ni0.5/HAP-OP: 0.0843
# 521. Pore Volume & Catalyst_Ni-Ce-CO2: 0.0843
# 522. Reaction Temperature & Catalyst_10Ni/g-Al2O3: 0.0843
# 523. Reaction Temperature & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0843
# 524. Reaction Temperature & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0843
# 525. Reaction Temperature & Catalyst_Ce(0)-NMA-COP: 0.0843
# 526. Reaction Temperature & Catalyst_Ce(1)-NMA-COP: 0.0843
# 527. Reaction Temperature & Catalyst_Ce(1)-NMA-IMP: 0.0843
# 528. Reaction Temperature & Catalyst_Ce(3)-NMA-COP: 0.0843
# 529. Reaction Temperature & Catalyst_Ce(3)-NMA-IMP: 0.0843
# 530. Reaction Temperature & Catalyst_Ce(5)-NMA-COP: 0.0843
# 531. Reaction Temperature & Catalyst_10%Ni/CeO2: 0.0843
# 532. Reaction Temperature & Catalyst_5%Ni/Al2O3: 0.0843
# 533. Reaction Temperature & Catalyst_5%Ni–3%MgO/Al2O: 0.0843
# 534. Reaction Temperature & Catalyst_Ce(5)-NMA-IMP: 0.0843
# 535. Reaction Temperature & Catalyst_15%Ni-MgO-Al2O3: 0.0843
# 536. Reaction Temperature & Catalyst_2.5%Ni-MgO-Al2O3: 0.0843
# 537. Reaction Temperature & Catalyst_5%Ni-MgO-Al2O3: 0.0843
# 538. Reaction Temperature & Catalyst_7.5%Ni-MgO-Al2O3: 0.0843
# 539. Reaction Temperature & Catalyst_10%Ni-MgO-Al2O3: 0.0843
# 540. Reaction Temperature & Catalyst_5%Ni–3%BaO/Al2O3: 0.0843
# 541. Reaction Temperature & Catalyst_5%Ni–3%CaO/Al2O3: 0.0843
# 542. H2-TPR Peak Temperature & Catalyst_10Ni-SBA-15: 0.0842
# 543. H2-TPR Peak Temperature & Catalyst_5Ni9Ce-SBA-15: 0.0842
# 544. Ni Particle Size & Catalyst_0.2Cu-Ni/SiO2: 0.0841
# 545. Ni Loading & Catalyst_Ni@SiO2-5 h: 0.0840
# 546. Ni Loading & Catalyst_Ni@SiO2-2 h: 0.0840
# 547. H2-TPR Peak Temperature & Catalyst_2.5%Ni-MgO-Al2O3: 0.0840
# 548. Pore Size & Catalyst_Ni-SiO2- NaOH: 0.0839
# 549. Surface Area & Catalyst_Ni@HSZ-reduced: 0.0839
# 550. CO2 Conversion & Catalyst_TAL75: 0.0838
# 551. H2-TPR Peak Temperature & Catalyst_10%Ni/CeO2: 0.0838
# 552. CH4 Conversion & Catalyst_Ni/15% CeO2− MgO: 0.0835
# 553. Ni Particle Size & Catalyst_5Ni/La2O3-TD: 0.0835
# 554. Syngas_Ratio & Catalyst_Ni-Zr Srf: 0.0835
# 555. Syngas_Ratio & Catalyst_Ni/9CS: 0.0834
# 556. Syngas_Ratio & Catalyst_5%B-Ni/SBA-15: 0.0833
# 557. Syngas_Ratio & Catalyst_Ni12MgAl: 0.0833
# 558. CO2 Conversion & Catalyst_TAL50: 0.0833
# 559. H2-TPR Peak Temperature & Catalyst_NAC: 0.0831
# 560. Syngas_Ratio & Catalyst_5ZrO-Ni/AL2O3: 0.0830
# 561. H2-TPR Peak Temperature & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0829
# 562. Surface Area & Catalyst_Ni/7La–Si: 0.0828
# 563. Reaction Temperature & Catalyst_Ni/SBA15: 0.0828
# 564. Pore Size & Catalyst_NAC: 0.0827
# 565. Ni Loading & Catalyst_NiPS@silica-0.6: 0.0825
# 566. Pore Volume & Catalyst_Ni-Ce-O2: 0.0825
# 567. Pore Volume & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0823
# 568. Pore Volume & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0823
# 569. Reaction Time & Catalyst_Ni(15)/perlite: 0.0823
# 570. Surface Area & Catalyst_NiCo/EXVTM-SiO2: 0.0822
# 571. H2-TPR Peak Temperature & Catalyst_Ni/CS-BM: 0.0819
# 572. GHSV & Catalyst_NHS-SiO2-S: 0.0819
# 573. Surface Area & Catalyst_Ni-Zr Pol: 0.0813
# 574. Syngas_Ratio & Catalyst_0.7 K-Ni/ MgAl2O4: 0.0813
# 575. H2-TPR Peak Temperature & Catalyst_Ce(3)-NMA-COP: 0.0813
# 576. Reaction Time & Catalyst_1.5Cu-Ni/SiO2: 0.0811
# 577. Modifier Electronegativity & Catalyst_Ce(1)-NMA-COP: 0.0809
# 578. Modifier Electronegativity & Catalyst_Ce(1)-NMA-IMP: 0.0809
# 579. Modifier Electronegativity & Catalyst_Ce(3)-NMA-COP: 0.0809
# 580. Modifier Electronegativity & Catalyst_Ce(3)-NMA-IMP: 0.0809
# 581. Modifier Electronegativity & Catalyst_Ce(5)-NMA-COP: 0.0809
# 582. Modifier Electronegativity & Catalyst_Ce(5)-NMA-IMP: 0.0809
# 583. H2-TPR Peak Temperature & Catalyst_NiCu/EXVTM-SiO2: 0.0808
# 584. Syngas_Ratio & Catalyst_Ni(15)/perlite: 0.0806
# 585. Pore Volume & Catalyst_Ni-Ce-H2: 0.0806
# 586. CH4 Conversion & Catalyst_Ni/Al2O3 -Nit: 0.0806
# 587. CH4 Conversion & Catalyst_Ni/CS-DP: 0.0804
# 588. CO2 Conversion & Catalyst_10AC-Ni/MgO-Al2O3: 0.0803
# 589. Surface Area & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0802
# 590. Pore Volume & Catalyst_Ni@SiO2-5 h: 0.0800
# 591. CO2 Conversion & Catalyst_Ce(1)-NMA-IMP: 0.0800
# 592. CH4 Conversion & Catalyst_Ni/La-SC: 0.0800
# 593. Pore Volume & Catalyst_0.5Cu-Ni/SiO2: 0.0800
# 594. GHSV & Catalyst_NAF: 0.0799
# 595. Pore Volume & Catalyst_Ce (10)-Ni(15)/perlite,: 0.0797
# 596. Pore Volume & Catalyst_Ce (20)-Ni(15)/perlite: 0.0797
# 597. Surface Area & Catalyst_NiCu/EXVTM-SiO2: 0.0796
# 598. Reaction Temperature & Catalyst_Ni(10)/CZ: 0.0795
# 599. Reaction Temperature & Catalyst_HNiZr10: 0.0795
# 600. Pore Size & Catalyst_Ni/SBA15: 0.0795
# 601. CH4 Conversion & Catalyst_Ni/Sn0.2−SiO2‑550: 0.0794
# 602. Ni Particle Size & Catalyst_Sn0.02 Ni/Al: 0.0793
# 603. Ni Particle Size & Catalyst_Sn0.04 Ni/Al: 0.0793
# 604. Pore Volume & Catalyst_TAL50: 0.0788
# 605. Pore Volume & Catalyst_10Ni-3Zr-MgAl2O4: 0.0788
# 606. Reaction Temperature & Catalyst_Ni/15% CeO2− MgO: 0.0788
# 607. Reaction Temperature & Catalyst_Ni/Al2O3 -Nit: 0.0788
# 608. Reaction Temperature & Catalyst_Ni/Al2O3 -Ole: 0.0788
# 609. Reaction Temperature & Catalyst_10AC-Ni/MgO-Al2O3: 0.0788
# 610. Reaction Temperature & Catalyst_Ni/MgO-Al2O3: 0.0788
# 611. Pore Volume & Catalyst_Ni/SC: 0.0788
# 612. Pore Volume & Catalyst_Ni/9CS: 0.0788
# 613. Surface Area & Catalyst_Ni/ Ce50− Zr50: 0.0785
# 614. Pore Size & Catalyst_11NiO/MgO-PWAC: 0.0784
# 615. Reaction Time & Catalyst_Ni/ Ce50− Zr50: 0.0783
# 616. Reaction Time & Catalyst_12.5%Ni-MgO-Al2O3: 0.0783
# 617. CO2 Conversion & Catalyst_12.5%Ni-MgO-Al2O3: 0.0782
# 618. Surface Area & Catalyst_Ni/EXVTM-SiO2: 0.0781
# 619. Ni Loading & H2-TPR Peak Temperature: 0.0780
# 620. H2-TPR Peak Temperature & Catalyst_Ni/CS-DP: 0.0780
# 621. CO2 Conversion & Catalyst_Ni-Zr Srf: 0.0779
# 622. Ni Particle Size & Catalyst_10Ni/Ce0.85La0.10Mn0.05O2: 0.0779
# 623. CH4 Conversion & Catalyst_10AC-Ni/MgO-Al2O3: 0.0777
# 624. Syngas_Ratio & Catalyst_Ni/18CS: 0.0776
# 625. Ni Loading & Catalyst_5Ni/La2O3-PP: 0.0774
# 626. Modifier Electronegativity & Catalyst_NAC: 0.0773
# 627. CO2 Conversion & Catalyst_Ce(1)-NMA-COP: 0.0773
# 628. Ni Particle Size & Catalyst_5Ni/La2O3-GNC\: 0.0772
# 629. Ratio of CH4 in Feed & Catalyst_Ni/MAD: 0.0772
# 630. Ratio of CH4 in Feed & Catalyst_Ni/MAD+PegMn: 0.0772
# 631. Ni Loading & Catalyst_5Ni/La2O3-GNC\: 0.0771
# 632. Ratio of CH4 in Feed & Catalyst_Ce (20)-Ni(15)/perlite: 0.0770
# 633. Ratio of CH4 in Feed & Catalyst_Ce (10)-Ni(15)/perlite,: 0.0770
# 634. Ratio of CH4 in Feed & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0770
# 635. Ratio of CH4 in Feed & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0770
# 636. Ratio of CH4 in Feed & Catalyst_Ni-LaCe 1:1: 0.0770
# 637. Ratio of CH4 in Feed & Catalyst_Ni-LaCe 1:4: 0.0770
# 638. Pore Volume & Catalyst_Ni (7)-MAl: 0.0769
# 639. Syngas_Ratio & Catalyst_Ni/La-ST: 0.0768
# 640. Surface Area & Catalyst_Ni/TiSiO2sg: 0.0768
# 641. CH4 Conversion & Catalyst_5Ni1Ce0.5La/ 30MgAl: 0.0766
# 642. H2-TPR Peak Temperature & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0766
# 643. Ni Loading & Catalyst_Ni−Mn/ Ce50−Zr50: 0.0766
# 644. Surface Area & Catalyst_Ni/CeZr: 0.0765
# 645. Ratio of CH4 in Feed & Catalyst_5Ni/La2O3-GNC\: 0.0765
# 646. Ratio of CH4 in Feed & Catalyst_5Ni/La2O3-PP: 0.0765
# 647. H2-TPR Peak Temperature & Catalyst_HNiZr3: 0.0765
# 648. Surface Area & Catalyst_Ni/TiSiO2gr: 0.0764
# 649. Surface Area & Catalyst_Ni-Ce Pol: 0.0764
# 650. CH4 Conversion & Catalyst_Ni/ Ce50− Zr50: 0.0764
# 651. H2-TPR Peak Temperature & Catalyst_Ce(1)-NMA-COP: 0.0762
# 652. H2-TPR Peak Temperature & Catalyst_Ce(5)-NMA-COP: 0.0762
# 653. CO2 Conversion & Catalyst_9%Y-NiO/ SBA-15: 0.0759
# 654. Ni Particle Size & Catalyst_Ni/FA-M2: 0.0758
# 655. Ni Particle Size & Catalyst_Ni/ZrSiO2sg: 0.0758
# 656. Reaction Time & Catalyst_5Ni/La2O3-GNC\: 0.0757
# 657. Reaction Time & Catalyst_5Ni/La2O3-PP: 0.0757
# 658. CO2 Conversion & Catalyst_Ni/La-SC: 0.0756
# 659. CH4 Conversion & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0756
# 660. H2-TPR Peak Temperature & Catalyst_Ni-LaCe 1:4: 0.0754
# 661. CH4 Conversion & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0753
# 662. GHSV & Catalyst_Ni/3.0La–Si-imp: 0.0753
# 663. GHSV & Catalyst_Ni/7La–Si: 0.0753
# 664. GHSV & Catalyst_Ni–3.0La/Si-imp: 0.0753
# 665. GHSV & Catalyst_Ni/2La–Si: 0.0753
# 666. GHSV & Catalyst_Ni/3La–Si: 0.0753
# 667. GHSV & Catalyst_Ni/5La–Si: 0.0753
# 668. GHSV & Catalyst_Ni/0La–Si: 0.0753
# 669. GHSV & Catalyst_Ni/1La–Si: 0.0753
# 670. Ni Particle Size & Catalyst_5Ni9Ce-SBA-15: 0.0753
# 671. Syngas_Ratio & Catalyst_NiCe: 0.0752
# 672. H2-TPR Peak Temperature & Catalyst_Ni/B-SiO2: 0.0751
# 673. H2-TPR Peak Temperature & Catalyst_10Ni-3La-MgAl2O4: 0.0751
# 674. Pore Volume & Catalyst_Ni-Ce-Ar: 0.0751
# 675. Surface Area & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0749
# 676. Ni Loading & Catalyst_Ni-Al/Fe-clay: 0.0748
# 677. Ni Loading & Catalyst_Ni (15)-MAl: 0.0748
# 678. Ni Loading & Catalyst_Ni0.15Mg0.85O: 0.0748
# 679. H2-TPR Peak Temperature & Catalyst_Ni/3.0La–Si-imp: 0.0748
# 680. Syngas_Ratio & Catalyst_Ni-Ce-H2: 0.0748
# 681. Ni Loading & Catalyst_Ni/SiO2-E: 0.0748
# 682. CO2 Conversion & Catalyst_Ni/CS-DP: 0.0747
# 683. CH4 Conversion & Catalyst_6PAl-10Ni: 0.0747
# 684. Syngas_Ratio & Catalyst_Ni/Al2O3: 0.0746
# 685. CO2 Conversion & Catalyst_TAL100: 0.0745
# 686. Pore Volume & Catalyst_Ni/La-ST: 0.0745
# 687. Pore Volume & Catalyst_Ni-LaCe 1:1: 0.0745
# 688. H2-TPR Peak Temperature & Catalyst_NiAl/La perovskite: 0.0745
# 689. Ni Loading & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.0744
# 690. H2-TPR Peak Temperature & Catalyst_NZH-c: 0.0744
# 691. Ni Particle Size & Catalyst_Ni10/SBA-15: 0.0743
# 692. CO2 Conversion & Catalyst_HNiZr10: 0.0742
# 693. CO2 Conversion & Catalyst_Ce(5)-NMA-IMP: 0.0741
# 694. GHSV & Catalyst_5Ni0.5La/ γ-Al2O3: 0.0740
# 695. GHSV & Catalyst_5Ni1Ce/ γ-Al2O3: 0.0740
# 696. GHSV & Catalyst_5Ni1Ce0.5La/ 30MgAl: 0.0740
# 697. CO2 Conversion & Catalyst_Ni/15% CeO2− MgO: 0.0740
# 698. CO2 Conversion & Catalyst_Ce(3)-NMA-COP: 0.0739
# 699. GHSV & Catalyst_10%Ni/CeO2: 0.0739
# 700. GHSV & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0739
# 701. GHSV & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0739
# 702. GHSV & Catalyst_5%Ni/Al2O3: 0.0739
# 703. GHSV & Catalyst_5%Ni–3%BaO/Al2O3: 0.0739
# 704. GHSV & Catalyst_5%Ni–3%CaO/Al2O3: 0.0739
# 705. GHSV & Catalyst_5%Ni–3%MgO/Al2O: 0.0739
# 706. GHSV & Catalyst_10Ni/g-Al2O3: 0.0739
# 707. Surface Area & Catalyst_10Ni-MgAl2O4: 0.0738
# 708. Modifier Electronegativity & Catalyst_HNiZr3: 0.0738
# 709. Modifier Electronegativity & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0738
# 710. Modifier Electronegativity & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0738
# 711. Ratio of CH4 in Feed & Catalyst_Ni/Al2O3: 0.0735
# 712. Pore Size & Catalyst_NiPS@silica-0.6: 0.0735
# 713. CO2 Conversion & Catalyst_5%Ni/Al2O3: 0.0733
# 714. CO2 Conversion & Catalyst_Ni/B-SiO2: 0.0733
# 715. Modifier Electronegativity & Catalyst_NAU: 0.0733
# 716. Modifier Electronegativity & Catalyst_NAW: 0.0733
# 717. Modifier Electronegativity & Catalyst_Ni10CeAl: 0.0733
# 718. Syngas_Ratio & Catalyst_Ni@SiO2-1 h: 0.0733
# 719. Surface Area & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0732
# 720. Pore Size & Catalyst_Ni/20% CeO2− MgO: 0.0732
# 721. Pore Size & Catalyst_Ni/Pal-UHP: 0.0732
# 722. CH4 Conversion & Catalyst_NHS-SiO2-S: 0.0731
# 723. CH4 Conversion & Catalyst_9%Y-NiO/ SBA-15: 0.0731
# 724. Ni Particle Size & Catalyst_Ni/10% CeO2− MgO: 0.0730
# 725. H2-TPR Peak Temperature & Catalyst_Ni/0La–Si: 0.0728
# 726. Pore Size & Catalyst_Ni/5% CeO2− MgO: 0.0726
# 727. Reaction Temperature & Catalyst_12.5%Ni-MgO-Al2O3: 0.0726
# 728. Surface Area & Catalyst_Ni-LaCe 1:1: 0.0725
# 729. CO2 Conversion & Catalyst_6%Y-NiO/SBA-15: 0.0724
# 730. Surface Area & Catalyst_Ni/La-SG: 0.0724
# 731. Surface Area & Catalyst_Ni/La-ST: 0.0723
# 732. Ni Particle Size & Catalyst_Ni/20% CeO2− MgO: 0.0723
# 733. Ni Particle Size & Catalyst_NiCo/mesoporousAl: 0.0723
# 734. Pore Volume & Catalyst_HNiZr3: 0.0722
# 735. Surface Area & Catalyst_Ni-LaCe 1:4: 0.0721
# 736. Modifier Electronegativity & Catalyst_10Ni-3Ce-MgAl2O4: 0.0721
# 737. Modifier Electronegativity & Catalyst_Ce-NHS-SiO2-S: 0.0721
# 738. Pore Size & Catalyst_Ce0.35Pr0.65O2: 0.0720
# 739. CO2 Conversion & Catalyst_5%Ni-MgO-Al2O3: 0.0720
# 740. Pore Volume & Catalyst_Ni-LaCe 1:4: 0.0718
# 741. Pore Size & Catalyst_NiPS@silica-0.4: 0.0718
# 742. Ni Loading & Catalyst_NiPS@silica-0.4: 0.0717
# 743. Ni Loading & Catalyst_Ni@SiO2-700: 0.0717
# 744. CH4 Conversion & Catalyst_6%Y-NiO/SBA-15: 0.0716
# 745. Pore Size & Catalyst_Ni@SiO2-2 h: 0.0715
# 746. CH4 Conversion & Catalyst_Ni/La-ME: 0.0715
# 747. CO2 Conversion & Catalyst_Ni/MgO-Al2O3(45%): 0.0715
# 748. Ni Particle Size & Catalyst_0.5Cu-Ni/SiO2: 0.0715
# 749. Ni Particle Size & Catalyst_10Ni/g-Al2O3: 0.0715
# 750. Pore Size & Catalyst_Ce0.2Pr0.8O2: 0.0714
# 751. H2-TPR Peak Temperature & Catalyst_Ni-Zr Pol: 0.0714
# 752. Pore Volume & Catalyst_Ni/18CS: 0.0714
# 753. Syngas_Ratio & Catalyst_0.5 K-Ni/MgAl2O4: 0.0712
# 754. Ni Particle Size & Catalyst_10Ni-3Zr-MgAl2O4: 0.0712
# 755. Surface Area & Catalyst_Ce (10)-Ni(15)/perlite,: 0.0711
# 756. Ni Loading & Catalyst_Ni/ Ce50− Zr50: 0.0709
# 757. Pore Size & CO2 Conversion: 0.0708
# 758. Surface Area & Catalyst_Ni/SC: 0.0707
# 759. H2-TPR Peak Temperature & Catalyst_5Ni0.5La/ γ-Al2O3: 0.0707
# 760. GHSV & Catalyst_0.2Cu-Ni/SiO2: 0.0705
# 761. GHSV & Catalyst_0.5Cu-Ni/SiO2: 0.0705
# 762. GHSV & Catalyst_1.5Cu-Ni/SiO2: 0.0705
# 763. Syngas_Ratio & Catalyst_2.5%Ni-MgO-Al2O3: 0.0705
# 764. CO2 Conversion & Catalyst_TAL0: 0.0705
# 765. Syngas_Ratio & Catalyst_Ni10CeAl: 0.0705
# 766. Modifier Electronegativity & Catalyst_Ni-Al/Fe-clay: 0.0703
# 767. Ni Particle Size & Catalyst_Ni-SiO2- Urea: 0.0703
# 768. CO2 Conversion & Catalyst_Ni/C-Al2O3-700: 0.0702
# 769. Surface Area & Catalyst_Ni-Zr Srf: 0.0702
# 770. Ni Particle Size & Catalyst_Ni(12.5)/Ce(7)-ZA: 0.0702
# 771. Ni Loading & Catalyst_Ni@SiO2-1 h: 0.0701
# 772. Modifier Electronegativity & Catalyst_10Ni-3La-MgAl2O4: 0.0700
# 773. H2-TPR Peak Temperature & Catalyst_10Ni-3Ce-MgAl2O4: 0.0699
# 774. H2-TPR Peak Temperature & Catalyst_Ni/LaAlO3: 0.0698
# 775. Syngas_Ratio & Catalyst_Ni/MgO-Al2O3(8%): 0.0698
# 776. H2-TPR Peak Temperature & Catalyst_Ni-Ce Pol: 0.0698
# 777. Pore Volume & Catalyst_10Ni-MgAl2O4: 0.0696
# 778. CO2 Conversion & Catalyst_7.5%Ni-MgO-Al2O3: 0.0695
# 779. CO2 Conversion & Catalyst_Ni(10)/CZ: 0.0694
# 780. CO2 Conversion & Catalyst_5Ni9Ce-SBA-15: 0.0694
# 781. Pore Volume & Catalyst_Ni/Ce: 0.0692
# 782. Pore Volume & Catalyst_10Ni-3Ce-MgAl2O4: 0.0692
# 783. GHSV & Catalyst_TAL100: 0.0691
# 784. GHSV & Catalyst_TAL0: 0.0691
# 785. GHSV & Catalyst_TAL25: 0.0691
# 786. GHSV & Catalyst_TAL50: 0.0691
# 787. GHSV & Catalyst_TAL75: 0.0691
# 788. Ni Particle Size & Catalyst_Ni/Al2O3 -Ole: 0.0691
# 789. Modifier Electronegativity & Catalyst_5%Ni–3%CaO/Al2O3: 0.0691
# 790. Modifier Electronegativity & Catalyst_Ni(15)/perlite: 0.0690
# 791. Syngas_Ratio & Catalyst_Ni-Ce-CO2: 0.0690
# 792. Syngas_Ratio & Catalyst_Ni-Ce-O2: 0.0690
# 793. Surface Area & Catalyst_Ce (20)-Ni(15)/perlite: 0.0689
# 794. CH4 Conversion & Catalyst_10%Ni/CeO2: 0.0689
# 795. Ni Loading & Catalyst_Ni-Al Srf: 0.0687
# 796. Ni Loading & Catalyst_Ni-Ce Srf: 0.0687
# 797. Ni Loading & Catalyst_Ni-Zr Srf: 0.0687
# 798. Ni Loading & Catalyst_5%Ni/Al2O3: 0.0687
# 799. Ni Loading & Catalyst_5%Ni–3%BaO/Al2O3: 0.0687
# 800. Ni Loading & Catalyst_5%Ni–3%CaO/Al2O3: 0.0687
# 801. Ni Loading & Catalyst_5%Ni–3%MgO/Al2O: 0.0687
# 802. Ni Loading & Catalyst_5%Ni-MgO-Al2O3: 0.0687
# 803. H2-TPR Peak Temperature & Catalyst_Ni/20% CeO2− MgO: 0.0687
# 804. GHSV & Catalyst_12.5%Ni-MgO-Al2O3: 0.0685
# 805. Ni Particle Size & Catalyst_10Ni-3Ce-MgAl2O4: 0.0684
# 806. Ratio of CH4 in Feed & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0684
# 807. Ratio of CH4 in Feed & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0684
# 808. Ratio of CH4 in Feed & Catalyst_10%Ni/CeO2: 0.0684
# 809. Ratio of CH4 in Feed & Catalyst_2.5%Ni-MgO-Al2O3: 0.0684
# 810. Ratio of CH4 in Feed & Catalyst_5%Ni-MgO-Al2O3: 0.0684
# 811. Ratio of CH4 in Feed & Catalyst_Ce(3)-NMA-IMP: 0.0684
# 812. Ratio of CH4 in Feed & Catalyst_Ce(5)-NMA-IMP: 0.0684
# 813. Ratio of CH4 in Feed & Catalyst_7.5%Ni-MgO-Al2O3: 0.0684
# 814. Ratio of CH4 in Feed & Catalyst_Ce(1)-NMA-IMP: 0.0684
# 815. Ratio of CH4 in Feed & Catalyst_10%Ni-MgO-Al2O3: 0.0684
# 816. Ratio of CH4 in Feed & Catalyst_Ce(5)-NMA-COP: 0.0684
# 817. Ratio of CH4 in Feed & Catalyst_15%Ni-MgO-Al2O3: 0.0684
# 818. Ratio of CH4 in Feed & Catalyst_Ce(0)-NMA-COP: 0.0684
# 819. Ratio of CH4 in Feed & Catalyst_Ce(1)-NMA-COP: 0.0684
# 820. Ratio of CH4 in Feed & Catalyst_Ce(3)-NMA-COP: 0.0684
# 821. Ratio of CH4 in Feed & Catalyst_3%Y-NiO/SBA-15: 0.0684
# 822. Ratio of CH4 in Feed & Catalyst_5%Ni/Al2O3: 0.0684
# 823. Ratio of CH4 in Feed & Catalyst_5%Ni–3%BaO/Al2O3: 0.0684
# 824. Ratio of CH4 in Feed & Catalyst_5%Ni–3%CaO/Al2O3: 0.0684
# 825. Ratio of CH4 in Feed & Catalyst_5%Ni–3%MgO/Al2O: 0.0684
# 826. Ratio of CH4 in Feed & Catalyst_6%Y-NiO/SBA-15: 0.0684
# 827. Ratio of CH4 in Feed & Catalyst_Ni10/SBA-15: 0.0684
# 828. Ratio of CH4 in Feed & Catalyst_9%Y-NiO/ SBA-15: 0.0684
# 829. Ratio of CH4 in Feed & Catalyst_10Ni/TS (50:50): 0.0684
# 830. Ratio of CH4 in Feed & Catalyst_10Ni/g-Al2O3: 0.0684
# 831. Ni Particle Size & Catalyst_Ni-SiO2- NaOH: 0.0683
# 832. Ni Particle Size & Catalyst_Ni/SiO2-E: 0.0683
# 833. CH4 Conversion & Catalyst_10Ni/DFSBA-15: 0.0683
# 834. CH4 Conversion & Catalyst_Ni10CeAl: 0.0682
# 835. Surface Area & Catalyst_Ni@SiO2-700: 0.0682
# 836. Surface Area & Catalyst_2%B-Ni/SBA-15: 0.0679
# 837. CO2 Conversion & Catalyst_10%Ni-MgO-Al2O3: 0.0678
# 838. Reaction Temperature & Modifier Electronegativity: 0.0677
# 839. Reaction Time & Catalyst_0.2Cu-Ni/SiO2: 0.0677
# 840. Reaction Time & Catalyst_0.5Cu-Ni/SiO2: 0.0677
# 841. H2-TPR Peak Temperature & Catalyst_Ni–3.0La/Si-imp: 0.0676
# 842. Ni Particle Size & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0676
# 843. Ni Particle Size & Catalyst_NiCe: 0.0676
# 844. H2-TPR Peak Temperature & Catalyst_NiCo/EXVTM-SiO2: 0.0675
# 845. Surface Area & Catalyst_Ni-4: 0.0675
# 846. CO2 Conversion & Catalyst_Ni/La-ME: 0.0675
# 847. Pore Size & Catalyst_Zr (10)-Ni(15)/ perlite: 0.0674
# 848. Ni Particle Size & Catalyst_Ni-SiO2- NH3·- H2O: 0.0673
# 849. Ni Particle Size & Catalyst_Ni@SiO2-1 h: 0.0673
# 850. Ni Particle Size & Catalyst_Ni5%Al2O3: 0.0673
# 851. CH4 Conversion & Catalyst_Ni-Zr Srf: 0.0671
# 852. CH4 Conversion & Catalyst_5%Ni-MgO-Al2O3: 0.0671
# 853. Ratio of CH4 in Feed & Catalyst_Ni0.5/HAP: 0.0671
# 854. Ratio of CH4 in Feed & Catalyst_NiY3-DLH: 0.0671
# 855. Ratio of CH4 in Feed & Catalyst_NiY4-DLH: 0.0671
# 856. Ratio of CH4 in Feed & Catalyst_NiY8-DLH: 0.0671
# 857. Ratio of CH4 in Feed & Catalyst_Cs–Ni–La2O3: 0.0671
# 858. Ratio of CH4 in Feed & Catalyst_K–Ni–La2O3: 0.0671
# 859. Ratio of CH4 in Feed & Catalyst_Li–Ni–La2O3: 0.0671
# 860. Ratio of CH4 in Feed & Catalyst_Mg–Ni–La2O3: 0.0671
# 861. Ratio of CH4 in Feed & Catalyst_Ni-Al/Fe-clay: 0.0671
# 862. Ratio of CH4 in Feed & Catalyst_Ni1.5/HAP-OP: 0.0671
# 863. Ratio of CH4 in Feed & Catalyst_Ni1/HAP-OP: 0.0671
# 864. Ratio of CH4 in Feed & Catalyst_Ni–La2O3: 0.0671
# 865. Ratio of CH4 in Feed & Catalyst_–Ni–La2O3: 0.0671
# 866. Ratio of CH4 in Feed & Catalyst_UNAU: 0.0671
# 867. Ratio of CH4 in Feed & Catalyst_HNiZr10: 0.0671
# 868. H2-TPR Peak Temperature & Catalyst_Ni/Al2O3: 0.0670
# 869. Ni Particle Size & Catalyst_10Ni-3La-MgAl2O4: 0.0670
# 870. Reaction Time & Catalyst_Ni/DFSBA-15: 0.0667
# 871. Pore Volume & Catalyst_NAC−1.2% Gd2O3: 0.0666
# 872. Pore Volume & Catalyst_Ni/La-SG: 0.0666
# 873. Ni Particle Size & Catalyst_10Ni-3Fe-MgAl2O4: 0.0666
# 874. Pore Size & Catalyst_HNiZr3: 0.0666
# 875. Pore Size & Catalyst_NiO−ZrO2: 0.0666
# 876. Ni Particle Size & Catalyst_Ni/La-ST: 0.0666
# 877. Ni Particle Size & Catalyst_Ni–3.0La/Si-imp: 0.0666
# 878. Reaction Time & Pore Size: 0.0665
# 879. Surface Area & Catalyst_UNAU: 0.0665
# 880. Surface Area & Catalyst_Ni/La-ME: 0.0665
# 881. Pore Size & Catalyst_5Ni/La2O3-TD: 0.0665
# 882. Syngas_Ratio & Catalyst_Ni/MgO-Al2O3(11%): 0.0664
# 883. CH4 Conversion & Catalyst_Ni5%Al2O3: 0.0663
# 884. Reaction Time & Catalyst_CB‐LDO: 0.0663
# 885. H2-TPR Peak Temperature & Catalyst_6PAl-10Ni: 0.0661
# 886. GHSV & Catalyst_Ni−Mn/ Ce50−Zr50: 0.0660
# 887. Ni Loading & Catalyst_Ni@SiO2-500: 0.0660
# 888. Reaction Time & Catalyst_Ce(0)-NMA-COP: 0.0660
# 889. Reaction Time & Catalyst_Ce(1)-NMA-COP: 0.0660
# 890. Reaction Time & Catalyst_Ce(1)-NMA-IMP: 0.0660
# 891. Reaction Time & Catalyst_Ce(3)-NMA-COP: 0.0660
# 892. Reaction Time & Catalyst_Ce(3)-NMA-IMP: 0.0660
# 893. Reaction Time & Catalyst_Ce(5)-NMA-COP: 0.0660
# 894. Reaction Time & Catalyst_Ce(5)-NMA-IMP: 0.0660
# 895. Surface Area & Catalyst_Ni-CeO2/SiO2: 0.0660
# 896. GHSV & Catalyst_Ni10CeAl: 0.0660
# 897. H2-TPR Peak Temperature & Catalyst_Ni/MgO-Al2O3: 0.0659
# 898. CH4 Conversion & Catalyst_Ni/C-Al2O3-700: 0.0659
# 899. Ni Loading & Catalyst_10ZrO-Ni/AL2O3: 0.0659
# 900. Surface Area & Catalyst_Ni-Ce Srf: 0.0659
# 901. Syngas_Ratio & Catalyst_Ni@SiO2-500: 0.0659
# 902. Pore Volume & Catalyst_NiY4-DLH: 0.0658
# 903. Pore Volume & Catalyst_1%B-Ni/SBA-15: 0.0658
# 904. Pore Volume & Catalyst_Ni/SH: 0.0658
# 905. Pore Volume & Catalyst_Ni/SN: 0.0658
# 906. Pore Size & Catalyst_Zr (20)-Ni(15)/perlite,: 0.0657
# 907. CH4 Conversion & Catalyst_5Ni1Ce/ γ-Al2O3: 0.0656
# 908. H2-TPR Peak Temperature & Catalyst_0.2 K-Ni/ MgAl2O4: 0.0655
# 909. Surface Area & Catalyst_Ni/SBA15: 0.0655
# 910. CO2 Conversion & Catalyst_Ni10CeAl: 0.0655
# 911. Modifier Electronegativity & Catalyst_NAC−1.2% Gd2O3: 0.0654
# 912. CO2 Conversion & Catalyst_Ni@HSZ-reduced: 0.0654
# 913. CO2 Conversion & Catalyst_Ni/MgO-Al2O3: 0.0654
# 914. Ratio of CH4 in Feed & Catalyst_Ni/La0.9Ca0.1AlO2.95: 0.0653
# 915. H2-TPR Peak Temperature & Catalyst_Ni/10% CeO2− MgO: 0.0652
# 916. H2-TPR Peak Temperature & Catalyst_10Ni-3Ca-MgAl2O4: 0.0651
# 917. Ni Loading & Catalyst_2ZrO-Ni/AL2O3: 0.0651
# 918. Syngas_Ratio & Catalyst_5Ni1Ce0.5La/ 30MgAl: 0.0651
# 919. Syngas_Ratio & Catalyst_Ni/La-SC: 0.0651
# 920. Ni Loading & Catalyst_5ZrO-Ni/AL2O3: 0.0649
# 921. CH4 Conversion & Catalyst_7.5%Ni-MgO-Al2O3: 0.0649
# 922. CH4 Conversion & Catalyst_5%Ni–3%BaO/Al2O3: 0.0648
# 923. H2-TPR Peak Temperature & Catalyst_Ni/1La–Si: 0.0647
# 924. Surface Area & Catalyst_Ni/15% CeO2− MgO: 0.0646
# 925. Surface Area & Catalyst_Ni (10)-MAl: 0.0646
# 926. Surface Area & Catalyst_Ni/La-HP: 0.0646
# 927. CO2 Conversion & Catalyst_Ce(0)-NMA-COP: 0.0646
# 928. Ni Particle Size & Catalyst_Ni-Al Pol: 0.0646
# 929. Modifier Electronegativity & Catalyst_Ni/SBA15: 0.0645
# 930. Modifier Electronegativity & Catalyst_10%Ni/Ce0.95Mn0.05: 0.0645
# 931. Modifier Electronegativity & Catalyst_Ni0.5/HAP-OP: 0.0645
# 932. H2-TPR Peak Temperature & Catalyst_Ni/ Ce50− Zr50: 0.0645
# 933. CO2 Conversion & Catalyst_Ni/MgO-Al2O3(8%): 0.0645
# 934. Ni Particle Size & Catalyst_NAF: 0.0644
# 935. H2-TPR Peak Temperature & Catalyst_10Ni-3Zr-MgAl2O4: 0.0643
# 936. Ni Particle Size & Catalyst_5Ni1Ce0.5La/ 30MgAl: 0.0643
# 937. Surface Area & Catalyst_CeO2@Ni/SiO2: 0.0643
# 938. CO2 Conversion & Catalyst_Ce(5)-NMA-COP: 0.0643
# 939. CH4 Conversion & Catalyst_Ni/MgO-Al2O3(8%): 0.0643
# 940. Reaction Temperature & Catalyst_5Ni0.5La/ γ-Al2O3: 0.0643
# 941. Reaction Temperature & Catalyst_5Ni1Ce/ γ-Al2O3: 0.0643
# 942. Reaction Temperature & Catalyst_5Ni1Ce0.5La/ 30MgAl: 0.0643
# 943. Reaction Temperature & Catalyst_NiPS@silica-0.4: 0.0643
# 944. Reaction Temperature & Catalyst_NiPS@silica-0.6: 0.0643
# 945. Reaction Temperature & Catalyst_Ni/La-HP: 0.0643
# 946. Reaction Temperature & Catalyst_Ni/La-ME: 0.0643
# 947. Reaction Temperature & Catalyst_Ni/La-SC: 0.0643
# 948. Reaction Temperature & Catalyst_Ni/La-ST: 0.0643
# 949. Reaction Temperature & Catalyst_Ni/La-SG: 0.0643
# 950. Reaction Temperature & Catalyst_NAC−1.2% Gd2O3: 0.0643
# 951. Reaction Temperature & Catalyst_Ni-8: 0.0643
# 952. Reaction Temperature & Catalyst_Ni@HSZ-reduced: 0.0643
# 953. Reaction Temperature & Catalyst_Ni@SiO2@ZrO2-reduced: 0.0643
# 954. Reaction Temperature & Catalyst_Ni-4: 0.0643
# 955. Reaction Temperature & Catalyst_Ni-6: 0.0643
# 956. Reaction Temperature & Catalyst_Ni-2: 0.0643
# 957. Reaction Temperature & Catalyst_Ni-IMP: 0.0643
# 958. Reaction Temperature & Catalyst_NiAl/La perovskite: 0.0643
# 959. Reaction Temperature & Catalyst_Ni/DFSBA-15: 0.0643
# 960. Reaction Temperature & Catalyst_10Ni/DFSBA-15: 0.0643
# 961. Reaction Temperature & Catalyst_15Ni/DFSBA-15: 0.0643
# 962. Reaction Temperature & Catalyst_5Ni/DFSBA-15: 0.0643
# 963. Reaction Temperature & Catalyst_Ni/CS-BM: 0.0643
# 964. Reaction Temperature & Catalyst_Ni/CS-DP: 0.0643
# 965. CH4 Conversion & Catalyst_5Ni0.5La/ γ-Al2O3: 0.0643
# 966. Pore Volume & Catalyst_Ni@SiO2: 0.0640
# 967. H2-TPR Peak Temperature & Catalyst_10Ni-3Fe-MgAl2O4: 0.0639
# 968. Ni Loading & Catalyst_Ni@SiO2-600: 0.0639
# 969. Ni Loading & GHSV: 0.0639
# 970. Reaction Time & Catalyst_5%Ni/Al2O3: 0.0639
# 971. Reaction Time & Catalyst_5%Ni–3%BaO/Al2O3: 0.0639
# 972. Reaction Time & Catalyst_5%Ni–3%CaO/Al2O3: 0.0639
# 973. Reaction Time & Catalyst_5%Ni–3%MgO/Al2O: 0.0639
# 974. Reaction Time & Catalyst_Ni-Ce Srf: 0.0639
# 975. Reaction Time & Catalyst_Ni-Zr Srf: 0.0639
# 976. Reaction Time & Catalyst_Ni-Al Srf: 0.0639
# 977. Reaction Time & Catalyst_15%Ni-MgO-Al2O3: 0.0639
# 978. Reaction Time & Catalyst_NAF: 0.0639
# 979. Reaction Time & Catalyst_10%Ni-MgO-Al2O3: 0.0639
# 980. Reaction Time & Catalyst_5%Ni-MgO-Al2O3: 0.0639
# 981. Reaction Time & Catalyst_7.5%Ni-MgO-Al2O3: 0.0639
# 982. Reaction Time & Catalyst_2.5%Ni-MgO-Al2O3: 0.0639
# 983. Reaction Time & Catalyst_10Ni/g-Al2O3: 0.0639
# 984. Reaction Time & Catalyst_10%Ni/Ce0.50Mn0.50 34.: 0.0639
# 985. Reaction Time & Catalyst_10%Ni/Ce0.75Mn0.25: 0.0639
# 986. Reaction Time & Catalyst_10%Ni/CeO2: 0.0639
# 987. Ni Particle Size & Catalyst_10Ni-3Ca-MgAl2O4: 0.0638
# 988. Pore Volume & CH4 Conversion: 0.0638
# 989. CO2 Conversion & Catalyst_15%Ni-MgO-Al2O3: 0.0637
# 990. H2-TPR Peak Temperature & Catalyst_15% Ni/CeO2 eMgO: 0.0636
# 991. Reaction Time & Surface Area: 0.0636
# 992. CH4 Conversion & Catalyst_NiCo/mesoporousAl: 0.0636
# 993. CO2 Conversion & Catalyst_10Ni-MgAl2O4: 0.0635
# 994. CH4 Conversion & Catalyst_Ni/CS-BM: 0.0635
# 995. Syngas_Ratio & Catalyst_NAF: 0.0634
# 996. Syngas_Ratio & Catalyst_Ni-Ce-Ar: 0.0633
# 997. Syngas_Ratio & Catalyst_Ni/3CS: 0.0633
# 998. H2-TPR Peak Temperature & Catalyst_0.5 K-Ni/MgAl2O4: 0.0632
# 999. H2-TPR Peak Temperature & Catalyst_0.7 K-Ni/ MgAl2O4: 0.0632
# 1000. Syngas_Ratio & Catalyst_Ni/MgO: 0.0632
#
# Which relationships do you want to visualize?
# Enter the starting number: 1
# Enter the ending number: 30
#
# Visualizing relationship between CH4 Conversion and CO2 Conversion:
# Visualizing relationship between Reaction Temperature and CH4 Conversion:
# Visualizing relationship between Reaction Temperature and CO2 Conversion:
# Visualizing relationship between Pore Volume and Surface Area:
# Visualizing relationship between CO2 Conversion and Syngas_Ratio:
# Visualizing relationship between CH4 Conversion and Syngas_Ratio:
# Visualizing relationship between Pore Size and Surface Area:
# Visualizing relationship between GHSV and Syngas_Ratio:
# Visualizing relationship between Surface Area and Ni Particle Size:
# Visualizing relationship between Pore Volume and Ni Particle Size:
# Visualizing relationship between Reaction Temperature and Reaction Time:
# Visualizing relationship between Pore Size and Catalyst_Ni0.5/HAP-OP:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Reaction Temperature and Syngas_Ratio:
# Visualizing relationship between Ni Particle Size and Catalyst_15% Ni/CeO2 eMgO:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Ni Loading and Pore Size:
# Visualizing relationship between Pore Size and Catalyst_Ni@SiO2-700:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Pore Size and Modifier Electronegativity:
# Visualizing relationship between Pore Size and Catalyst_5Ni/La2O3-GNC\:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Reaction Time and GHSV:
# Visualizing relationship between Ni Loading and Catalyst_Ni(15)/perlite:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Ratio of CH4 in Feed and Catalyst_NAU:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Ratio of CH4 in Feed and Catalyst_NAW:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Pore Volume and H2-TPR Peak Temperature:
# Visualizing relationship between Pore Size and Catalyst_15% Ni/CeO2 eMgO:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between H2-TPR Peak Temperature and Ni Particle Size:
# Visualizing relationship between Ratio of CH4 in Feed and Catalyst_NAC:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Ni Particle Size and Catalyst_Ni-Zr Srf:
# Consider using pair plot for relationships across multiple features.
#
# Visualizing relationship between Ni Loading and Pore Volume:
# Visualizing relationship between Surface Area and H2-TPR Peak Temperature:
# Visualizing relationship between Ratio of CH4 in Feed and Surface Area:
# Based on the visualizations and correlation analysis:
#   - A strong positive correlation exists between CH4 Conversion and CO2 Conversion.
#     As CH4 Conversion increases, CO2 Conversion tends to increase as well.
#   - The relationship between Reaction Temperature and CH4 Conversion is moderate or weak.
#   - The relationship between Reaction Temperature and CO2 Conversion is moderate or weak.
#   - The relationship between Pore Volume and Surface Area is moderate or weak.
#   - The relationship between CO2 Conversion and Syngas_Ratio is moderate or weak.
#   - The relationship between CH4 Conversion and Syngas_Ratio is moderate or weak.
#   - The relationship between Pore Size and Surface Area is moderate or weak.
#   - The relationship between GHSV and Syngas_Ratio is moderate or weak.
#   - The relationship between Surface Area and Ni Particle Size is moderate or weak.
#   - The relationship between Pore Volume and Ni Particle Size is moderate or weak.
#   - The relationship between Reaction Temperature and Reaction Time is moderate or weak.
#   - The relationship between Pore Size and Catalyst_Ni0.5/HAP-OP is moderate or weak.
#   - The relationship between Reaction Temperature and Syngas_Ratio is moderate or weak.
#   - The relationship between Ni Particle Size and Catalyst_15% Ni/CeO2 eMgO is moderate or weak.
#   - The relationship between Ni Loading and Pore Size is moderate or weak.
#   - The relationship between Pore Size and Catalyst_Ni@SiO2-700 is moderate or weak.
#   - The relationship between Pore Size and Modifier Electronegativity is moderate or weak.
#   - The relationship between Pore Size and Catalyst_5Ni/La2O3-GNC\ is moderate or weak.
#   - The relationship between Reaction Time and GHSV is moderate or weak.
#   - The relationship between Ni Loading and Catalyst_Ni(15)/perlite is moderate or weak.
#   - The relationship between Ratio of CH4 in Feed and Catalyst_NAU is moderate or weak.
#   - The relationship between Ratio of CH4 in Feed and Catalyst_NAW is moderate or weak.
#   - The relationship between Pore Volume and H2-TPR Peak Temperature is moderate or weak.
#   - The relationship between Pore Size and Catalyst_15% Ni/CeO2 eMgO is moderate or weak.
#   - The relationship between H2-TPR Peak Temperature and Ni Particle Size is moderate or weak.
#   - The relationship between Ratio of CH4 in Feed and Catalyst_NAC is moderate or weak.
#   - The relationship between Ni Particle Size and Catalyst_Ni-Zr Srf is moderate or weak.
#   - The relationship between Ni Loading and Pore Volume is moderate or weak.
#   - The relationship between Surface Area and H2-TPR Peak Temperature is moderate or weak.
#   - The relationship between Ratio of CH4 in Feed and Surface Area is moderate or weak.

# %%
# Identify most influential variables on CH4 Conversion

CH4_Conversion_correlations = []
for col in df_encoded.columns:
  if col != 'CH4 Conversion':
    correlation = df_encoded['CH4 Conversion'].corr(df_encoded[col])
    CH4_Conversion_correlations.append((col, abs(correlation)))

# Identify most influential variables on CO2 Conversion

CO2_Conversion_correlations = []
for col in df_encoded.columns:
  if col != 'CO2 Conversion':
    correlation = df_encoded['CO2 Conversion'].corr(df_encoded[col])
    CO2_Conversion_correlations.append((col, abs(correlation)))

 # Identify most influential variables on Syngas Ratio

Syngas_Ratio_correlations = []
for col in df_encoded.columns:
  if col != 'Syngas_Ratio':
    correlation = df_encoded['Syngas_Ratio'].corr(df_encoded[col])
    Syngas_Ratio_correlations.append((col, abs(correlation)))

# Sort by correlation strength
CH4_Conversion_correlations.sort(key=lambda x: x[1], reverse=True)
CO2_Conversion_correlations.sort(key=lambda x: x[1], reverse=True)
Syngas_Ratio_correlations.sort(key=lambda x: x[1], reverse=True)

#CH4
# Display the most influential variables
print("\nMost influential variables on CH4 Conversion:")
for col, correlation in CH4_Conversion_correlations[:5]:  # Show top 5
  print(f"  - {col}: {correlation:.2f}")

# Explain the influence of variables on CH4 Conversion
print("\nBased on the correlation analysis:")
for col, correlation in CH4_Conversion_correlations[:5]:
  if correlation > 0.7:
    print(f"  - {col} has a strong positive influence on CH4 Conversion.")
    print(f"    Higher values of {col} tend to result in higher CH4 Conversion.")
  elif correlation < -0.7:
    print(f"  - {col} has a strong negative influence on CH4 Conversion.")
    print(f"    Higher values of {col} tend to result in lower CH4 Conversion.")
  else:
    print(f"  - The influence of {col} on CH4 Conversion is moderate or weak.")

#CO2
# Display the most influential variables
print("\nMost influential variables on CO2 Conversion:")
for col, correlation in CO2_Conversion_correlations[:5]:  # Show top 5
  print(f"  - {col}: {correlation:.2f}")

# Explain the influence of variables on CO2 Conversion
print("\nBased on the correlation analysis:")
for col, correlation in CO2_Conversion_correlations[:5]:
  if correlation > 0.7:
    print(f"  - {col} has a strong positive influence on CO2 Conversion.")
    print(f"    Higher values of {col} tend to result in higher CO2 Conversion.")
  elif correlation < -0.7:
    print(f"  - {col} has a strong negative influence on CO2 Conversion.")
    print(f"    Higher values of {col} tend to result in lower CO2 Conversion.")
  else:
    print(f"  - The influence of {col} on CO2 Conversion is moderate or weak.")

#syngas
# Display the most influential variables
print("\nMost influential variables on Syngas Ratio:")
for col, correlation in Syngas_Ratio_correlations[:5]:  # Show top 5
  print(f"  - {col}: {correlation:.2f}")

# Explain the influence of variables on Syngas Ratio
print("\nBased on the correlation analysis:")
for col, correlation in Syngas_Ratio_correlations[:5]:
  if correlation > 0.7:
    print(f"  - {col} has a strong positive influence on Syngas Ratio.")
    print(f"    Higher values of {col} tend to result in higher Syngas Ratio.")
  elif correlation < -0.7:
    print(f"  - {col} has a strong negative influence on Syngas Ratio.")
    print(f"    Higher values of {col} tend to result in lower Syngas Ratio.")
  else:
    print(f"  - The influence of {col} on Syngas Ratio is moderate or weak.")
# Out:
# Most influential variables on CH4 Conversion:
#   - CO2 Conversion: 0.90
#   - Reaction Temperature: 0.65
#   - Syngas_Ratio: 0.52
#   - Ratio of CH4 in Feed: 0.18
#   - Modifier Electronegativity: 0.17
#
# Based on the correlation analysis:
#   - CO2 Conversion has a strong positive influence on CH4 Conversion.
#     Higher values of CO2 Conversion tend to result in higher CH4 Conversion.
#   - The influence of Reaction Temperature on CH4 Conversion is moderate or weak.
#   - The influence of Syngas_Ratio on CH4 Conversion is moderate or weak.
#   - The influence of Ratio of CH4 in Feed on CH4 Conversion is moderate or weak.
#   - The influence of Modifier Electronegativity on CH4 Conversion is moderate or weak.
#
# Most influential variables on CO2 Conversion:
#   - CH4 Conversion: 0.90
#   - Reaction Temperature: 0.64
#   - Syngas_Ratio: 0.54
#   - Ratio of CH4 in Feed: 0.17
#   - Catalyst_Ni-SiO2- NaOH: 0.15
#
# Based on the correlation analysis:
#   - CH4 Conversion has a strong positive influence on CO2 Conversion.
#     Higher values of CH4 Conversion tend to result in higher CO2 Conversion.
#   - The influence of Reaction Temperature on CO2 Conversion is moderate or weak.
#   - The influence of Syngas_Ratio on CO2 Conversion is moderate or weak.
#   - The influence of Ratio of CH4 in Feed on CO2 Conversion is moderate or weak.
#   - The influence of Catalyst_Ni-SiO2- NaOH on CO2 Conversion is moderate or weak.
#
# Most influential variables on Syngas Ratio:
#   - CO2 Conversion: 0.54
#   - CH4 Conversion: 0.52
#   - GHSV: 0.34
#   - Reaction Temperature: 0.27
#   - Surface Area: 0.17
#
# Based on the correlation analysis:
#   - The influence of CO2 Conversion on Syngas Ratio is moderate or weak.
#   - The influence of CH4 Conversion on Syngas Ratio is moderate or weak.
#   - The influence of GHSV on Syngas Ratio is moderate or weak.
#   - The influence of Reaction Temperature on Syngas Ratio is moderate or weak.
#   - The influence of Surface Area on Syngas Ratio is moderate or weak.
